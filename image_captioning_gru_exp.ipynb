# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import random
import copy
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
from torch.optim.lr_scheduler import _LRScheduler

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torchsummary import summary

from sklearn import manifold
from torchvision.datasets import VisionDataset, Flickr30k
from collections import Counter
import pickle
from tqdm import tqdm
import nltk
from collections import defaultdict
import torchvision.models as models
from torch.nn.utils.rnn import pack_padded_sequence
from nltk.corpus import stopwords

# %%
# !pip install torchsummary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.10/dist-packages (1.5.1)

# %%
# !pip install --user -U nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/req_command.py", line 242, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 397, in resolve
#     self._add_to_criteria(self.state.criteria, r, parent=None)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 173, in _add_to_criteria
#     if not criterion.candidates:
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/structs.py", line 156, in __bool__
#     return bool(self._sequence)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 155, in __bool__
#     return any(self)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 143, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 90, in _iter_built_with_inserted
#     for version, func in infos:
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/factory.py", line 279, in iter_index_candidate_infos
#     result = self._finder.find_best_candidate(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/index/package_finder.py", line 890, in find_best_candidate
#     candidates = self.find_all_candidates(project_name)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/index/package_finder.py", line 831, in find_all_candidates
#     page_candidates = list(page_candidates_it)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/index/sources.py", line 134, in page_candidates
#     yield from self._candidates_from_page(self._link)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/index/package_finder.py", line 795, in process_project_url
#     page_links = list(parse_links(index_response))
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/index/collector.py", line 223, in wrapper_wrapper
#     return list(fn(page))
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/index/collector.py", line 238, in parse_links
#     link = Link.from_json(file, page.url)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/models/link.py", line 258, in from_json
#     file_url = file_data.get("url")
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/main.py", line 79, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     return run(options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 206, in exc_logging_wrapper
#     logger.critical("Operation cancelled by user")
#   File "/usr/lib/python3.10/logging/__init__.py", line 1524, in critical
#     self._log(CRITICAL, msg, args, **kwargs)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1622, in _log
#     record = self.makeRecord(self.name, level, fn, lno, msg, args,
#   File "/usr/lib/python3.10/logging/__init__.py", line 1591, in makeRecord
#     rv = _logRecordFactory(name, level, fn, lno, msg, args, exc_info, func,
#   File "/usr/lib/python3.10/logging/__init__.py", line 309, in __init__
#     if (args and len(args) == 1 and isinstance(args[0], collections.abc.Mapping)
# KeyboardInterrupt
# ^C

# %%
# !pip install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)

# %%
# !pip install -U scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.1.0)

# %%
# !pip3 install torch torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %%shell
# tar -xvzf /content/drive/MyDrive/flickr30k-images.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# flickr30k-images/5354904685.jpg
# flickr30k-images/5354911151.jpg
# flickr30k-images/535529555.jpg
# flickr30k-images/5356236664.jpg
# flickr30k-images/5356318668.jpg
# flickr30k-images/535830521.jpg
# flickr30k-images/5359437945.jpg
# flickr30k-images/5361355399.jpg
# flickr30k-images/53614287.jpg
# flickr30k-images/536147209.jpg
# flickr30k-images/5361551308.jpg
# flickr30k-images/536156200.jpg
# flickr30k-images/5362687336.jpg
# flickr30k-images/5363528971.jpg
# flickr30k-images/5363903246.jpg
# flickr30k-images/5364849864.jpg
# flickr30k-images/536495604.jpg
# flickr30k-images/5365075444.jpg
# flickr30k-images/536533294.jpg
# flickr30k-images/536537638.jpg
# flickr30k-images/5366770416.jpg
# flickr30k-images/536718060.jpg
# flickr30k-images/536721406.jpg
# flickr30k-images/5367322642.jpg
# flickr30k-images/536739751.jpg
# flickr30k-images/536828916.jpg
# flickr30k-images/536904709.jpg
# flickr30k-images/5369771639.jpg
# flickr30k-images/5370581509.jpg
# flickr30k-images/537069478.jpg
# flickr30k-images/5371109894.jpg
# flickr30k-images/5371186400.jpg
# flickr30k-images/5371247136.jpg
# flickr30k-images/5371507831.jpg
# flickr30k-images/5371586024.jpg
# flickr30k-images/537222436.jpg
# flickr30k-images/537225246.jpg
# flickr30k-images/537230454.jpg
# flickr30k-images/537359971.jpg
# flickr30k-images/5373606679.jpg
# flickr30k-images/5373649841.jpg
# flickr30k-images/537390477.jpg
# flickr30k-images/5374764034.jpg
# flickr30k-images/537479916.jpg
# flickr30k-images/5375199269.jpg
# flickr30k-images/5375305047.jpg
# flickr30k-images/537532165.jpg
# flickr30k-images/537559285.jpg
# flickr30k-images/537579448.jpg
# flickr30k-images/537586194.jpg
# flickr30k-images/537628742.jpg
# flickr30k-images/5377361.jpg
# flickr30k-images/537758332.jpg
# flickr30k-images/537875659.jpg
# flickr30k-images/5379229830.jpg
# flickr30k-images/537960889.jpg
# flickr30k-images/537968424.jpg
# flickr30k-images/5380411758.jpg
# flickr30k-images/5380554509.jpg
# flickr30k-images/5381043783.jpg
# flickr30k-images/5381043991.jpg
# flickr30k-images/5381102989.jpg
# flickr30k-images/5381104643.jpg
# flickr30k-images/5381185036.jpg
# flickr30k-images/5381657104.jpg
# flickr30k-images/5381663472.jpg
# flickr30k-images/5381684062.jpg
# flickr30k-images/538271607.jpg
# flickr30k-images/538345634.jpg
# flickr30k-images/5384132543.jpg
# flickr30k-images/5384744603.jpg
# flickr30k-images/5385069995.jpg
# flickr30k-images/5385135432.jpg
# flickr30k-images/5386097747.jpg
# flickr30k-images/538638526.jpg
# flickr30k-images/5387261695.jpg
# flickr30k-images/538825260.jpg
# flickr30k-images/5388634274.jpg
# flickr30k-images/5388693640.jpg
# flickr30k-images/5389294129.jpg
# flickr30k-images/538953637.jpg
# flickr30k-images/5389902618.jpg
# flickr30k-images/538990552.jpg
# flickr30k-images/5390483760.jpg
# flickr30k-images/539061478.jpg
# flickr30k-images/5391079713.jpg
# flickr30k-images/5391728144.jpg
# flickr30k-images/5392145976.jpg
# flickr30k-images/539218410.jpg
# flickr30k-images/5393330953.jpg
# flickr30k-images/539493423.jpg
# flickr30k-images/539493431.jpg
# flickr30k-images/53955170.jpg
# flickr30k-images/539659873.jpg
# flickr30k-images/539667015.jpg
# flickr30k-images/539676201.jpg
# flickr30k-images/539705321.jpg
# flickr30k-images/539744890.jpg
# flickr30k-images/539750844.jpg
# flickr30k-images/539751252.jpg
# flickr30k-images/539761097.jpg
# flickr30k-images/5397894822.jpg
# flickr30k-images/5397926630.jpg
# flickr30k-images/539801139.jpg
# flickr30k-images/5398619523.jpg
# flickr30k-images/539871204.jpg
# flickr30k-images/539881707.jpg
# flickr30k-images/5399620276.jpg
# flickr30k-images/5400154.jpg
# flickr30k-images/5400824262.jpg
# flickr30k-images/5402085.jpg
# flickr30k-images/5402872122.jpg
# flickr30k-images/5403340942.jpg
# flickr30k-images/5403366009.jpg
# flickr30k-images/5403369219.jpg
# flickr30k-images/540338917.jpg
# flickr30k-images/5403632578.jpg
# flickr30k-images/540381751.jpg
# flickr30k-images/5403970454.jpg
# flickr30k-images/5403972062.jpg
# flickr30k-images/5403974296.jpg
# flickr30k-images/5403974988.jpg
# flickr30k-images/5403982362.jpg
# flickr30k-images/540436324.jpg
# flickr30k-images/540436782.jpg
# flickr30k-images/5404491005.jpg
# flickr30k-images/5404607703.jpg
# flickr30k-images/5404931227.jpg
# flickr30k-images/5404950935.jpg
# flickr30k-images/540503255.jpg
# flickr30k-images/5405076022.jpg
# flickr30k-images/5405095380.jpg
# flickr30k-images/5405152070.jpg
# flickr30k-images/5405152538.jpg
# flickr30k-images/5405213054.jpg
# flickr30k-images/540604040.jpg
# flickr30k-images/5406927495.jpg
# flickr30k-images/540721368.jpg
# flickr30k-images/540746143.jpg
# flickr30k-images/540791807.jpg
# flickr30k-images/5408196820.jpg
# flickr30k-images/5408199015.jpg
# flickr30k-images/5408221986.jpg
# flickr30k-images/540873795.jpg
# flickr30k-images/5408820009.jpg
# flickr30k-images/540943543.jpg
# flickr30k-images/541046380.jpg
# flickr30k-images/5410472318.jpg
# flickr30k-images/541063419.jpg
# flickr30k-images/541063517.jpg
# flickr30k-images/5411481517.jpg
# flickr30k-images/5411504795.jpg
# flickr30k-images/5412034666.jpg
# flickr30k-images/5412119890.jpg
# flickr30k-images/541342477.jpg
# flickr30k-images/541497191.jpg
# flickr30k-images/5415070045.jpg
# flickr30k-images/5415181095.jpg
# flickr30k-images/541537091.jpg
# flickr30k-images/541552675.jpg
# flickr30k-images/5415557808.jpg
# flickr30k-images/5415557940.jpg
# flickr30k-images/5415761675.jpg
# flickr30k-images/5415762131.jpg
# flickr30k-images/5416301879.jpg
# flickr30k-images/5416571561.jpg
# flickr30k-images/5416898306.jpg
# flickr30k-images/5417456446.jpg
# flickr30k-images/5418130134.jpg
# flickr30k-images/54185885.jpg
# flickr30k-images/5419013581.jpg
# flickr30k-images/5419038647.jpg
# flickr30k-images/5419695587.jpg
# flickr30k-images/5420247403.jpg
# flickr30k-images/5420765124.jpg
# flickr30k-images/5421108099.jpg
# flickr30k-images/542179694.jpg
# flickr30k-images/542269487.jpg
# flickr30k-images/5423080316.jpg
# flickr30k-images/5423102604.jpg
# flickr30k-images/542317719.jpg
# flickr30k-images/5423856409.jpg
# flickr30k-images/542389533.jpg
# flickr30k-images/542405691.jpg
# flickr30k-images/54242432.jpg
# flickr30k-images/5425075136.jpg
# flickr30k-images/54260190.jpg
# flickr30k-images/542605701.jpg
# flickr30k-images/5426416610.jpg
# flickr30k-images/542648687.jpg
# flickr30k-images/542714962.jpg
# flickr30k-images/5428317596.jpg
# flickr30k-images/5428390334.jpg
# flickr30k-images/542850900.jpg
# flickr30k-images/5428747894.jpg
# flickr30k-images/5429241344.jpg
# flickr30k-images/543007912.jpg
# flickr30k-images/5430267989.jpg
# flickr30k-images/5430568615.jpg
# flickr30k-images/543102698.jpg
# flickr30k-images/5431166070.jpg
# flickr30k-images/5432374521.jpg
# flickr30k-images/543264612.jpg
# flickr30k-images/5432673825.jpg
# flickr30k-images/543291644.jpg
# flickr30k-images/5433157092.jpg
# flickr30k-images/543326592.jpg
# flickr30k-images/543363241.jpg
# flickr30k-images/5434071249.jpg
# flickr30k-images/5435865134.jpg
# flickr30k-images/543603259.jpg
# flickr30k-images/543613917.jpg
# flickr30k-images/5436250638.jpg
# flickr30k-images/5436553157.jpg
# flickr30k-images/5436966915.jpg
# flickr30k-images/5436986554.jpg
# flickr30k-images/543712974.jpg
# flickr30k-images/543797471.jpg
# flickr30k-images/5438152388.jpg
# flickr30k-images/543875752.jpg
# flickr30k-images/543940240.jpg
# flickr30k-images/5440115287.jpg
# flickr30k-images/544039045.jpg
# flickr30k-images/544039061.jpg
# flickr30k-images/544046588.jpg
# flickr30k-images/544122267.jpg
# flickr30k-images/5441246798.jpg
# flickr30k-images/5441315625.jpg
# flickr30k-images/544149309.jpg
# flickr30k-images/5441804056.jpg
# flickr30k-images/5442112383.jpg
# flickr30k-images/544257613.jpg
# flickr30k-images/544301311.jpg
# flickr30k-images/5444535493.jpg
# flickr30k-images/5444724.jpg
# flickr30k-images/5445317867.jpg
# flickr30k-images/5445530361.jpg
# flickr30k-images/544576742.jpg
# flickr30k-images/5446041790.jpg
# flickr30k-images/5446138396.jpg
# flickr30k-images/5446415631.jpg
# flickr30k-images/5447361965.jpg
# flickr30k-images/544764927.jpg
# flickr30k-images/5447755663.jpg
# flickr30k-images/5447844412.jpg
# flickr30k-images/54501196.jpg
# flickr30k-images/5450688421.jpg
# flickr30k-images/5451473560.jpg
# flickr30k-images/5452434213.jpg
# flickr30k-images/5453323381.jpg
# flickr30k-images/5453806694.jpg
# flickr30k-images/5453936030.jpg
# flickr30k-images/5454221964.jpg
# flickr30k-images/5455437647.jpg
# flickr30k-images/5455501634.jpg
# flickr30k-images/5455508814.jpg
# flickr30k-images/5455524571.jpg
# flickr30k-images/5456046008.jpg
# flickr30k-images/5456725416.jpg
# flickr30k-images/5456862756.jpg
# flickr30k-images/5457465605.jpg
# flickr30k-images/5457524393.jpg
# flickr30k-images/5457524513.jpg
# flickr30k-images/5457873764.jpg
# flickr30k-images/5458061796.jpg
# flickr30k-images/5459493511.jpg
# flickr30k-images/5460100066.jpg
# flickr30k-images/5460845581.jpg
# flickr30k-images/5465722830.jpg
# flickr30k-images/5466266163.jpg
# flickr30k-images/5467111335.jpg
# flickr30k-images/5468029953.jpg
# flickr30k-images/5468293105.jpg
# flickr30k-images/5468460528.jpg
# flickr30k-images/5468626430.jpg
# flickr30k-images/5469569530.jpg
# flickr30k-images/5470620936.jpg
# flickr30k-images/54723805.jpg
# flickr30k-images/5475015553.jpg
# flickr30k-images/5475934236.jpg
# flickr30k-images/5476674072.jpg
# flickr30k-images/5476688378.jpg
# flickr30k-images/5477270023.jpg
# flickr30k-images/5477626138.jpg
# flickr30k-images/5477639022.jpg
# flickr30k-images/5477641512.jpg
# flickr30k-images/5479540752.jpg
# flickr30k-images/5479743540.jpg
# flickr30k-images/5479752383.jpg
# flickr30k-images/5480435624.jpg
# flickr30k-images/54817316.jpg
# flickr30k-images/5482951453.jpg
# flickr30k-images/5483441438.jpg
# flickr30k-images/5483599902.jpg
# flickr30k-images/5484283629.jpg
# flickr30k-images/5484875008.jpg
# flickr30k-images/5484929515.jpg
# flickr30k-images/5485593000.jpg
# flickr30k-images/5485896726.jpg
# flickr30k-images/5486058256.jpg
# flickr30k-images/548751378.jpg
# flickr30k-images/5487530231.jpg
# flickr30k-images/5488532211.jpg
# flickr30k-images/5489135871.jpg
# flickr30k-images/5489602545.jpg
# flickr30k-images/5491045483.jpg
# flickr30k-images/5491397203.jpg
# flickr30k-images/5491402223.jpg
# flickr30k-images/5491874786.jpg
# flickr30k-images/549520317.jpg
# flickr30k-images/5495428438.jpg
# flickr30k-images/5496383084.jpg
# flickr30k-images/5496383618.jpg
# flickr30k-images/549639456.jpg
# flickr30k-images/549887636.jpg
# flickr30k-images/5498941021.jpg
# flickr30k-images/549945760.jpg
# flickr30k-images/549948800.jpg
# flickr30k-images/5499892202.jpg
# flickr30k-images/549998716.jpg
# flickr30k-images/5500138655.jpg
# flickr30k-images/5500650754.jpg
# flickr30k-images/5500695312.jpg
# flickr30k-images/5500955489.jpg
# flickr30k-images/550119995.jpg
# flickr30k-images/5501226985.jpg
# flickr30k-images/5501235989.jpg
# flickr30k-images/5501340599.jpg
# flickr30k-images/5501805647.jpg
# flickr30k-images/5501819854.jpg
# flickr30k-images/5501830558.jpg
# flickr30k-images/5501939468.jpg
# flickr30k-images/5501939710.jpg
# flickr30k-images/5501940668.jpg
# flickr30k-images/5502202358.jpg
# flickr30k-images/5502929205.jpg
# flickr30k-images/5503437581.jpg
# flickr30k-images/55034909.jpg
# flickr30k-images/5503955724.jpg
# flickr30k-images/5504028572.jpg
# flickr30k-images/5504365495.jpg
# flickr30k-images/5504368601.jpg
# flickr30k-images/5504963988.jpg
# flickr30k-images/5505219003.jpg
# flickr30k-images/550610362.jpg
# flickr30k-images/5506383509.jpg
# flickr30k-images/5506385451.jpg
# flickr30k-images/5506394073.jpg
# flickr30k-images/5506395415.jpg
# flickr30k-images/5506399373.jpg
# flickr30k-images/5506407501.jpg
# flickr30k-images/5506988830.jpg
# flickr30k-images/5506994278.jpg
# flickr30k-images/5507087401.jpg
# flickr30k-images/5507574163.jpg
# flickr30k-images/5508346028.jpg
# flickr30k-images/5508398736.jpg
# flickr30k-images/5510073103.jpg
# flickr30k-images/5510989691.jpg
# flickr30k-images/5511458367.jpg
# flickr30k-images/5511459001.jpg
# flickr30k-images/5511460259.jpg
# flickr30k-images/5511461225.jpg
# flickr30k-images/5512062568.jpg
# flickr30k-images/551315867.jpg
# flickr30k-images/5513216171.jpg
# flickr30k-images/55135290.jpg
# flickr30k-images/5513727638.jpg
# flickr30k-images/551403320.jpg
# flickr30k-images/551664516.jpg
# flickr30k-images/5517849007.jpg
# flickr30k-images/5518762083.jpg
# flickr30k-images/5518762299.jpg
# flickr30k-images/5518763793.jpg
# flickr30k-images/5518764727.jpg
# flickr30k-images/5518766647.jpg
# flickr30k-images/5519354264.jpg
# flickr30k-images/5519356022.jpg
# flickr30k-images/5519356488.jpg
# flickr30k-images/5519359130.jpg
# flickr30k-images/5520203447.jpg
# flickr30k-images/5521593413.jpg
# flickr30k-images/5521996.jpg
# flickr30k-images/5522177900.jpg
# flickr30k-images/5522182662.jpg
# flickr30k-images/5522482326.jpg
# flickr30k-images/5523001543.jpg
# flickr30k-images/5523249598.jpg
# flickr30k-images/5523538212.jpg
# flickr30k-images/5523586446.jpg
# flickr30k-images/552498500.jpg
# flickr30k-images/5526034.jpg
# flickr30k-images/5526424589.jpg
# flickr30k-images/5526668006.jpg
# flickr30k-images/5526795355.jpg
# flickr30k-images/552863655.jpg
# flickr30k-images/5529428571.jpg
# flickr30k-images/553009435.jpg
# flickr30k-images/5532294954.jpg
# flickr30k-images/553267106.jpg
# flickr30k-images/5533686373.jpg
# flickr30k-images/5534272962.jpg
# flickr30k-images/5534280202.jpg
# flickr30k-images/5534793306.jpg
# flickr30k-images/5535626115.jpg
# flickr30k-images/5536018727.jpg
# flickr30k-images/5536018957.jpg
# flickr30k-images/5536107008.jpg
# flickr30k-images/5536289343.jpg
# flickr30k-images/553854589.jpg
# flickr30k-images/55389857.jpg
# flickr30k-images/553918837.jpg
# flickr30k-images/5539761047.jpg
# flickr30k-images/5539804678.jpg
# flickr30k-images/55406417.jpg
# flickr30k-images/5541308296.jpg
# flickr30k-images/5542011192.jpg
# flickr30k-images/554215758.jpg
# flickr30k-images/5542771977.jpg
# flickr30k-images/5543458745.jpg
# flickr30k-images/55438559.jpg
# flickr30k-images/5543900069.jpg
# flickr30k-images/55442802.jpg
# flickr30k-images/554526471.jpg
# flickr30k-images/55470226.jpg
# flickr30k-images/55473406.jpg
# flickr30k-images/554774472.jpg
# flickr30k-images/5547783051.jpg
# flickr30k-images/5549756426.jpg
# flickr30k-images/5550039813.jpg
# flickr30k-images/555014891.jpg
# flickr30k-images/5550325552.jpg
# flickr30k-images/5550546246.jpg
# flickr30k-images/5551968198.jpg
# flickr30k-images/5551993461.jpg
# flickr30k-images/555378351.jpg
# flickr30k-images/5554366099.jpg
# flickr30k-images/5558170783.jpg
# flickr30k-images/5558592.jpg
# flickr30k-images/5558777621.jpg
# flickr30k-images/5559471351.jpg
# flickr30k-images/5559644896.jpg
# flickr30k-images/5561301943.jpg
# flickr30k-images/5562469374.jpg
# flickr30k-images/5562975921.jpg
# flickr30k-images/5563345549.jpg
# flickr30k-images/5563446889.jpg
# flickr30k-images/5565536413.jpg
# flickr30k-images/5565570899.jpg
# flickr30k-images/556568556.jpg
# flickr30k-images/556601134.jpg
# flickr30k-images/5566135246.jpg
# flickr30k-images/5566972.jpg
# flickr30k-images/5570219.jpg
# flickr30k-images/5570254.jpg
# flickr30k-images/557101732.jpg
# flickr30k-images/5571017359.jpg
# flickr30k-images/5571949283.jpg
# flickr30k-images/5572347874.jpg
# flickr30k-images/5572351880.jpg
# flickr30k-images/5572655622.jpg
# flickr30k-images/5573511334.jpg
# flickr30k-images/5574382134.jpg
# flickr30k-images/557601144.jpg
# flickr30k-images/5576659557.jpg
# flickr30k-images/557721978.jpg
# flickr30k-images/5579811387.jpg
# flickr30k-images/5581356064.jpg
# flickr30k-images/558161347.jpg
# flickr30k-images/5582659196.jpg
# flickr30k-images/5582687203.jpg
# flickr30k-images/5583005407.jpg
# flickr30k-images/5583280537.jpg
# flickr30k-images/5583327265.jpg
# flickr30k-images/558338473.jpg
# flickr30k-images/5583674969.jpg
# flickr30k-images/5583837367.jpg
# flickr30k-images/5584269779.jpg
# flickr30k-images/5584378669.jpg
# flickr30k-images/5585791618.jpg
# flickr30k-images/5585975540.jpg
# flickr30k-images/5586190109.jpg
# flickr30k-images/558620122.jpg
# flickr30k-images/558665373.jpg
# flickr30k-images/5586889028.jpg
# flickr30k-images/5587744215.jpg
# flickr30k-images/5587932348.jpg
# flickr30k-images/5588403950.jpg
# flickr30k-images/5589601689.jpg
# flickr30k-images/5589693661.jpg
# flickr30k-images/5590283636.jpg
# flickr30k-images/55903788.jpg
# flickr30k-images/559065775.jpg
# flickr30k-images/559102835.jpg
# flickr30k-images/5591545538.jpg
# flickr30k-images/5592562548.jpg
# flickr30k-images/5593628279.jpg
# flickr30k-images/5593634551.jpg
# flickr30k-images/559404730.jpg
# flickr30k-images/5594417687.jpg
# flickr30k-images/5595611219.jpg
# flickr30k-images/5595612913.jpg
# flickr30k-images/5597473807.jpg
# flickr30k-images/5597767097.jpg
# flickr30k-images/5597911580.jpg
# flickr30k-images/559852881.jpg
# flickr30k-images/559910846.jpg
# flickr30k-images/559944506.jpg
# flickr30k-images/56012054.jpg
# flickr30k-images/56012468.jpg
# flickr30k-images/56012911.jpg
# flickr30k-images/56013036.jpg
# flickr30k-images/5602731697.jpg
# flickr30k-images/5602737557.jpg
# flickr30k-images/560278886.jpg
# flickr30k-images/5603329477.jpg
# flickr30k-images/5604836194.jpg
# flickr30k-images/5604836629.jpg
# flickr30k-images/5604852363.jpg
# flickr30k-images/5605133486.jpg
# flickr30k-images/5605455443.jpg
# flickr30k-images/560671767.jpg
# flickr30k-images/5606758706.jpg
# flickr30k-images/5608476880.jpg
# flickr30k-images/5608502395.jpg
# flickr30k-images/5609573810.jpg
# flickr30k-images/5610848512.jpg
# flickr30k-images/5611391594.jpg
# flickr30k-images/5611717202.jpg
# flickr30k-images/561179884.jpg
# flickr30k-images/561179890.jpg
# flickr30k-images/561199893.jpg
# flickr30k-images/561204294.jpg
# flickr30k-images/5612808611.jpg
# flickr30k-images/5613689797.jpg
# flickr30k-images/5613922717.jpg
# flickr30k-images/561417861.jpg
# flickr30k-images/5614228719.jpg
# flickr30k-images/5614715384.jpg
# flickr30k-images/5615068475.jpg
# flickr30k-images/5615077255.jpg
# flickr30k-images/5615083329.jpg
# flickr30k-images/5615084425.jpg
# flickr30k-images/5615134449.jpg
# flickr30k-images/5615652514.jpg
# flickr30k-images/5615654150.jpg
# flickr30k-images/5615654776.jpg
# flickr30k-images/5615711650.jpg
# flickr30k-images/5615716320.jpg
# flickr30k-images/5617549557.jpg
# flickr30k-images/561906323.jpg
# flickr30k-images/561940436.jpg
# flickr30k-images/5620724486.jpg
# flickr30k-images/5621180809.jpg
# flickr30k-images/5621600104.jpg
# flickr30k-images/5621916498.jpg
# flickr30k-images/562242613.jpg
# flickr30k-images/5622966650.jpg
# flickr30k-images/5623287052.jpg
# flickr30k-images/5624522.jpg
# flickr30k-images/562588230.jpg
# flickr30k-images/5626262792.jpg
# flickr30k-images/5626622789.jpg
# flickr30k-images/562928217.jpg
# flickr30k-images/5629300.jpg
# flickr30k-images/5629464725.jpg
# flickr30k-images/5631556013.jpg
# flickr30k-images/5632141892.jpg
# flickr30k-images/5633096756.jpg
# flickr30k-images/5633231430.jpg
# flickr30k-images/5633423671.jpg
# flickr30k-images/5633758879.jpg
# flickr30k-images/563404108.jpg
# flickr30k-images/563508330.jpg
# flickr30k-images/5635975939.jpg
# flickr30k-images/5637347272.jpg
# flickr30k-images/5637361857.jpg
# flickr30k-images/5637498751.jpg
# flickr30k-images/5637994240.jpg
# flickr30k-images/563803038.jpg
# flickr30k-images/5639026536.jpg
# flickr30k-images/5639106614.jpg
# flickr30k-images/5640452539.jpg
# flickr30k-images/5641021474.jpg
# flickr30k-images/5642901248.jpg
# flickr30k-images/5643010407.jpg
# flickr30k-images/5645857612.jpg
# flickr30k-images/5646792433.jpg
# flickr30k-images/5648321.jpg
# flickr30k-images/5648828783.jpg
# flickr30k-images/5648957534.jpg
# flickr30k-images/56489627.jpg
# flickr30k-images/56494233.jpg
# flickr30k-images/5650197379.jpg
# flickr30k-images/565088263.jpg
# flickr30k-images/5651210045.jpg
# flickr30k-images/5651347663.jpg
# flickr30k-images/5651514000.jpg
# flickr30k-images/5652699228.jpg
# flickr30k-images/565314823.jpg
# flickr30k-images/5654749179.jpg
# flickr30k-images/5654845057.jpg
# flickr30k-images/565490650.jpg
# flickr30k-images/565605894.jpg
# flickr30k-images/5656207480.jpg
# flickr30k-images/5657272299.jpg
# flickr30k-images/5657884044.jpg
# flickr30k-images/5658123607.jpg
# flickr30k-images/5658127907.jpg
# flickr30k-images/5660037266.jpg
# flickr30k-images/566077886.jpg
# flickr30k-images/5661511556.jpg
# flickr30k-images/5661511576.jpg
# flickr30k-images/5661996549.jpg
# flickr30k-images/5662260935.jpg
# flickr30k-images/566384456.jpg
# flickr30k-images/566397227.jpg
# flickr30k-images/566446626.jpg
# flickr30k-images/56659639.jpg
# flickr30k-images/566794036.jpg
# flickr30k-images/566794440.jpg
# flickr30k-images/5668948557.jpg
# flickr30k-images/566921157.jpg
# flickr30k-images/5669382831.jpg
# flickr30k-images/566945636.jpg
# flickr30k-images/5669914204.jpg
# flickr30k-images/5669959908.jpg
# flickr30k-images/5671379503.jpg
# flickr30k-images/5672704774.jpg
# flickr30k-images/567459261.jpg
# flickr30k-images/5675148300.jpg
# flickr30k-images/567526452.jpg
# flickr30k-images/5676066044.jpg
# flickr30k-images/5676123641.jpg
# flickr30k-images/5676123833.jpg
# flickr30k-images/5676780431.jpg
# flickr30k-images/5676781835.jpg
# flickr30k-images/567713601.jpg
# flickr30k-images/5678896414.jpg
# flickr30k-images/567903453.jpg
# flickr30k-images/567909573.jpg
# flickr30k-images/567921691.jpg
# flickr30k-images/5679390502.jpg
# flickr30k-images/5680345504.jpg
# flickr30k-images/5681124098.jpg
# flickr30k-images/5681130869.jpg
# flickr30k-images/5682364328.jpg
# flickr30k-images/5683406436.jpg
# flickr30k-images/5683548982.jpg
# flickr30k-images/5684145463.jpg
# flickr30k-images/5684720360.jpg
# flickr30k-images/5684881640.jpg
# flickr30k-images/5685007801.jpg
# flickr30k-images/5686865855.jpg
# flickr30k-images/5686868227.jpg
# flickr30k-images/5687357997.jpg
# flickr30k-images/568765229.jpg
# flickr30k-images/5687832945.jpg
# flickr30k-images/5687833791.jpg
# flickr30k-images/5687835083.jpg
# flickr30k-images/5687835693.jpg
# flickr30k-images/5687843849.jpg
# flickr30k-images/5687925512.jpg
# flickr30k-images/5688558209.jpg
# flickr30k-images/568940932.jpg
# flickr30k-images/5690228281.jpg
# flickr30k-images/5690229093.jpg
# flickr30k-images/5690804296.jpg
# flickr30k-images/5690859699.jpg
# flickr30k-images/5691210724.jpg
# flickr30k-images/5691273194.jpg
# flickr30k-images/5691273322.jpg
# flickr30k-images/5691273582.jpg
# flickr30k-images/5691283784.jpg
# flickr30k-images/5692076205.jpg
# flickr30k-images/5692144392.jpg
# flickr30k-images/56927229.jpg
# flickr30k-images/5694314894.jpg
# flickr30k-images/5695964851.jpg
# flickr30k-images/5696547236.jpg
# flickr30k-images/5696549500.jpg
# flickr30k-images/5696581092.jpg
# flickr30k-images/5696880945.jpg
# flickr30k-images/5696948391.jpg
# flickr30k-images/5701331807.jpg
# flickr30k-images/5701726173.jpg
# flickr30k-images/5701786491.jpg
# flickr30k-images/5703140155.jpg
# flickr30k-images/5704623726.jpg
# flickr30k-images/570520724.jpg
# flickr30k-images/5705242347.jpg
# flickr30k-images/5706094499.jpg
# flickr30k-images/5706454140.jpg
# flickr30k-images/5706580028.jpg
# flickr30k-images/57078880.jpg
# flickr30k-images/5708913531.jpg
# flickr30k-images/5708913719.jpg
# flickr30k-images/5709070770.jpg
# flickr30k-images/570990225.jpg
# flickr30k-images/570996053.jpg
# flickr30k-images/570999731.jpg
# flickr30k-images/571000535.jpg
# flickr30k-images/571002259.jpg
# flickr30k-images/5710348031.jpg
# flickr30k-images/5710857189.jpg
# flickr30k-images/571130875.jpg
# flickr30k-images/5712029145.jpg
# flickr30k-images/5712096379.jpg
# flickr30k-images/5713261883.jpg
# flickr30k-images/5714006990.jpg
# flickr30k-images/5714048502.jpg
# flickr30k-images/571507143.jpg
# flickr30k-images/5715657613.jpg
# flickr30k-images/571602538.jpg
# flickr30k-images/571612606.jpg
# flickr30k-images/571621280.jpg
# flickr30k-images/5716219952.jpg
# flickr30k-images/5716554915.jpg
# flickr30k-images/5718253019.jpg
# flickr30k-images/571865477.jpg
# flickr30k-images/5718656424.jpg
# flickr30k-images/57193495.jpg
# flickr30k-images/5721131714.jpg
# flickr30k-images/5721250516.jpg
# flickr30k-images/572135297.jpg
# flickr30k-images/5721362205.jpg
# flickr30k-images/5721400077.jpg
# flickr30k-images/5721468367.jpg
# flickr30k-images/572149383.jpg
# flickr30k-images/5721495953.jpg
# flickr30k-images/5721530415.jpg
# flickr30k-images/572163357.jpg
# flickr30k-images/572206753.jpg
# flickr30k-images/5722658.jpg
# flickr30k-images/5723273191.jpg
# flickr30k-images/5723818088.jpg
# flickr30k-images/5723822388.jpg
# flickr30k-images/5726018984.jpg
# flickr30k-images/572618443.jpg
# flickr30k-images/57264404.jpg
# flickr30k-images/5726809479.jpg
# flickr30k-images/5726810305.jpg
# flickr30k-images/5727359138.jpg
# flickr30k-images/572764040.jpg
# flickr30k-images/5727946383.jpg
# flickr30k-images/5728470160.jpg
# flickr30k-images/5728544416.jpg
# flickr30k-images/5728602543.jpg
# flickr30k-images/5729814.jpg
# flickr30k-images/5730196560.jpg
# flickr30k-images/5730226613.jpg
# flickr30k-images/5730444205.jpg
# flickr30k-images/5730564191.jpg
# flickr30k-images/5730792187.jpg
# flickr30k-images/5731343120.jpg
# flickr30k-images/5731856709.jpg
# flickr30k-images/5732157460.jpg
# flickr30k-images/5732433781.jpg
# flickr30k-images/5732659631.jpg
# flickr30k-images/5732777684.jpg
# flickr30k-images/5733209542.jpg
# flickr30k-images/5733760.jpg
# flickr30k-images/573385626.jpg
# flickr30k-images/5735222957.jpg
# flickr30k-images/5735645786.jpg
# flickr30k-images/573594802.jpg
# flickr30k-images/5737431445.jpg
# flickr30k-images/5737434301.jpg
# flickr30k-images/5737435305.jpg
# flickr30k-images/5737982354.jpg
# flickr30k-images/5738179350.jpg
# flickr30k-images/5738778049.jpg
# flickr30k-images/5738816035.jpg
# flickr30k-images/5739332706.jpg
# flickr30k-images/5739363696.jpg
# flickr30k-images/573946592.jpg
# flickr30k-images/5739923608.jpg
# flickr30k-images/57417224.jpg
# flickr30k-images/57417274.jpg
# flickr30k-images/574181.jpg
# flickr30k-images/57422853.jpg
# flickr30k-images/574274795.jpg
# flickr30k-images/5742849511.jpg
# flickr30k-images/574306153.jpg
# flickr30k-images/5743199540.jpg
# flickr30k-images/5743380092.jpg
# flickr30k-images/5744253993.jpg
# flickr30k-images/5745120660.jpg
# flickr30k-images/5745387160.jpg
# flickr30k-images/5745422329.jpg
# flickr30k-images/5747873823.jpg
# flickr30k-images/574793535.jpg
# flickr30k-images/5748015019.jpg
# flickr30k-images/5748024681.jpg
# flickr30k-images/5748029405.jpg
# flickr30k-images/5748912722.jpg
# flickr30k-images/5749795798.jpg
# flickr30k-images/5750611277.jpg
# flickr30k-images/5753038227.jpg
# flickr30k-images/5753085652.jpg
# flickr30k-images/5754249309.jpg
# flickr30k-images/57544895.jpg
# flickr30k-images/5755891783.jpg
# flickr30k-images/575636303.jpg
# flickr30k-images/5756366794.jpg
# flickr30k-images/575737626.jpg
# flickr30k-images/5757492662.jpg
# flickr30k-images/5757814392.jpg
# flickr30k-images/575853856.jpg
# flickr30k-images/5758838589.jpg
# flickr30k-images/5759383826.jpg
# flickr30k-images/5759427006.jpg
# flickr30k-images/5759882364.jpg
# flickr30k-images/576075451.jpg
# flickr30k-images/576093768.jpg
# flickr30k-images/5761090545.jpg
# flickr30k-images/5761270577.jpg
# flickr30k-images/5761877589.jpg
# flickr30k-images/5762196405.jpg
# flickr30k-images/5762731952.jpg
# flickr30k-images/5766437977.jpg
# flickr30k-images/576768199.jpg
# flickr30k-images/5767811093.jpg
# flickr30k-images/576875301.jpg
# flickr30k-images/57691053.jpg
# flickr30k-images/576920249.jpg
# flickr30k-images/5769574991.jpg
# flickr30k-images/5769761872.jpg
# flickr30k-images/5769934076.jpg
# flickr30k-images/5769937988.jpg
# flickr30k-images/5769959745.jpg
# flickr30k-images/5769961721.jpg
# flickr30k-images/5770115416.jpg
# flickr30k-images/5770961200.jpg
# flickr30k-images/5771011772.jpg
# flickr30k-images/5771078209.jpg
# flickr30k-images/5771732.jpg
# flickr30k-images/5774624102.jpg
# flickr30k-images/5775029982.jpg
# flickr30k-images/5776639717.jpg
# flickr30k-images/5777129645.jpg
# flickr30k-images/5779172980.jpg
# flickr30k-images/5780791171.jpg
# flickr30k-images/5781162449.jpg
# flickr30k-images/578274277.jpg
# flickr30k-images/5783690677.jpg
# flickr30k-images/5783876648.jpg
# flickr30k-images/5784245184.jpg
# flickr30k-images/578644583.jpg
# flickr30k-images/578679799.jpg
# flickr30k-images/5787072819.jpg
# flickr30k-images/5788177425.jpg
# flickr30k-images/5788678128.jpg
# flickr30k-images/5788687372.jpg
# flickr30k-images/578873882.jpg
# flickr30k-images/5788742746.jpg
# flickr30k-images/5788772871.jpg
# flickr30k-images/578910261.jpg
# flickr30k-images/5789294140.jpg
# flickr30k-images/5789670474.jpg
# flickr30k-images/578996360.jpg
# flickr30k-images/5790434381.jpg
# flickr30k-images/579055546.jpg
# flickr30k-images/5790840713.jpg
# flickr30k-images/5791070.jpg
# flickr30k-images/5791244.jpg
# flickr30k-images/5791274887.jpg
# flickr30k-images/5791568.jpg
# flickr30k-images/5793396150.jpg
# flickr30k-images/5793422010.jpg
# flickr30k-images/5794131663.jpg
# flickr30k-images/5794205434.jpg
# flickr30k-images/5794346640.jpg
# flickr30k-images/5794490455.jpg
# flickr30k-images/5796947698.jpg
# flickr30k-images/5797618847.jpg
# flickr30k-images/5797756884.jpg
# flickr30k-images/5797838137.jpg
# flickr30k-images/57989758.jpg
# flickr30k-images/5802826308.jpg
# flickr30k-images/5804672051.jpg
# flickr30k-images/58046927.jpg
# flickr30k-images/5806030158.jpg
# flickr30k-images/5806219410.jpg
# flickr30k-images/5806326544.jpg
# flickr30k-images/5807099586.jpg
# flickr30k-images/5811788459.jpg
# flickr30k-images/58121544.jpg
# flickr30k-images/5812770731.jpg
# flickr30k-images/581419370.jpg
# flickr30k-images/581630745.jpg
# flickr30k-images/5817561743.jpg
# flickr30k-images/58198686.jpg
# flickr30k-images/5820828817.jpg
# flickr30k-images/5820895953.jpg
# flickr30k-images/5821129557.jpg
# flickr30k-images/5821135681.jpg
# flickr30k-images/5821273614.jpg
# flickr30k-images/5821273816.jpg
# flickr30k-images/5821457712.jpg
# flickr30k-images/5821457818.jpg
# flickr30k-images/5822092748.jpg
# flickr30k-images/5822381051.jpg
# flickr30k-images/5822381095.jpg
# flickr30k-images/5822447877.jpg
# flickr30k-images/5823012892.jpg
# flickr30k-images/5823013198.jpg
# flickr30k-images/5823026973.jpg
# flickr30k-images/5823145889.jpg
# flickr30k-images/5823147109.jpg
# flickr30k-images/5823148675.jpg
# flickr30k-images/5823151095.jpg
# flickr30k-images/5823285867.jpg
# flickr30k-images/5823310445.jpg
# flickr30k-images/5823326999.jpg
# flickr30k-images/5823716566.jpg
# flickr30k-images/5823813436.jpg
# flickr30k-images/5825226259.jpg
# flickr30k-images/5825529550.jpg
# flickr30k-images/5826148145.jpg
# flickr30k-images/582653438.jpg
# flickr30k-images/5826678076.jpg
# flickr30k-images/5826844495.jpg
# flickr30k-images/582788646.jpg
# flickr30k-images/5828028061.jpg
# flickr30k-images/582899605.jpg
# flickr30k-images/5829317322.jpg
# flickr30k-images/5829359094.jpg
# flickr30k-images/5829827359.jpg
# flickr30k-images/5829835806.jpg
# flickr30k-images/583087629.jpg
# flickr30k-images/583090328.jpg
# flickr30k-images/5831085623.jpg
# flickr30k-images/583174725.jpg
# flickr30k-images/5831994264.jpg
# flickr30k-images/5832821999.jpg
# flickr30k-images/5835573414.jpg
# flickr30k-images/58357057.jpg
# flickr30k-images/5836131322.jpg
# flickr30k-images/58363928.jpg
# flickr30k-images/58363930.jpg
# flickr30k-images/58368365.jpg
# flickr30k-images/583865081.jpg
# flickr30k-images/5840087663.jpg
# flickr30k-images/5840187633.jpg
# flickr30k-images/5840232264.jpg
# flickr30k-images/5843047066.jpg
# flickr30k-images/5843048042.jpg
# flickr30k-images/5843164517.jpg
# flickr30k-images/5843625835.jpg
# flickr30k-images/5843713244.jpg
# flickr30k-images/5843921596.jpg
# flickr30k-images/584484388.jpg
# flickr30k-images/5845214651.jpg
# flickr30k-images/5846691766.jpg
# flickr30k-images/5846714531.jpg
# flickr30k-images/5847006092.jpg
# flickr30k-images/584726817.jpg
# flickr30k-images/5847719619.jpg
# flickr30k-images/5847749710.jpg
# flickr30k-images/5848679932.jpg
# flickr30k-images/5849278148.jpg
# flickr30k-images/5850474494.jpg
# flickr30k-images/5851176801.jpg
# flickr30k-images/5851818256.jpg
# flickr30k-images/5851970989.jpg
# flickr30k-images/5852468422.jpg
# flickr30k-images/5852667073.jpg
# flickr30k-images/5855641283.jpg
# flickr30k-images/58579865.jpg
# flickr30k-images/5858406299.jpg
# flickr30k-images/5858851.jpg
# flickr30k-images/5859913309.jpg
# flickr30k-images/5861612441.jpg
# flickr30k-images/586384606.jpg
# flickr30k-images/5865511903.jpg
# flickr30k-images/5866079837.jpg
# flickr30k-images/5867606.jpg
# flickr30k-images/5868688859.jpg
# flickr30k-images/5869269064.jpg
# flickr30k-images/5870019388.jpg
# flickr30k-images/5870433117.jpg
# flickr30k-images/5870701819.jpg
# flickr30k-images/5871026012.jpg
# flickr30k-images/5871124252.jpg
# flickr30k-images/5871970.jpg
# flickr30k-images/5872331129.jpg
# flickr30k-images/58727908.jpg
# flickr30k-images/587604325.jpg
# flickr30k-images/5876512276.jpg
# flickr30k-images/5877914411.jpg
# flickr30k-images/5879279230.jpg
# flickr30k-images/58803866.jpg
# flickr30k-images/5880786104.jpg
# flickr30k-images/5881141060.jpg
# flickr30k-images/5882565072.jpg
# flickr30k-images/5884154559.jpg
# flickr30k-images/5884235216.jpg
# flickr30k-images/5885058292.jpg
# flickr30k-images/5885795251.jpg
# flickr30k-images/5885795253.jpg
# flickr30k-images/5885865851.jpg
# flickr30k-images/58867718.jpg
# flickr30k-images/5888131040.jpg
# flickr30k-images/5888200593.jpg
# flickr30k-images/5888746167.jpg
# flickr30k-images/5890401192.jpg
# flickr30k-images/5891694046.jpg
# flickr30k-images/5891971963.jpg
# flickr30k-images/5892888081.jpg
# flickr30k-images/5892895879.jpg
# flickr30k-images/5892931627.jpg
# flickr30k-images/5892947599.jpg
# flickr30k-images/5893468050.jpg
# flickr30k-images/5893481130.jpg
# flickr30k-images/5893485204.jpg
# flickr30k-images/5893495086.jpg
# flickr30k-images/5893612531.jpg
# flickr30k-images/5893948473.jpg
# flickr30k-images/5893980467.jpg
# flickr30k-images/5894545772.jpg
# flickr30k-images/5894551808.jpg
# flickr30k-images/58957719.jpg
# flickr30k-images/5896386113.jpg
# flickr30k-images/5896923627.jpg
# flickr30k-images/5897020465.jpg
# flickr30k-images/5897050379.jpg
# flickr30k-images/5897266539.jpg
# flickr30k-images/5897279071.jpg
# flickr30k-images/5897297135.jpg
# flickr30k-images/5897488202.jpg
# flickr30k-images/5897560750.jpg
# flickr30k-images/589759896.jpg
# flickr30k-images/5897657716.jpg
# flickr30k-images/5897700952.jpg
# flickr30k-images/5897843552.jpg
# flickr30k-images/5897874398.jpg
# flickr30k-images/5899467604.jpg
# flickr30k-images/5899468014.jpg
# flickr30k-images/5899799040.jpg
# flickr30k-images/5901845159.jpg
# flickr30k-images/5902222408.jpg
# flickr30k-images/5902223492.jpg
# flickr30k-images/5902372520.jpg
# flickr30k-images/5902389941.jpg
# flickr30k-images/59027529.jpg
# flickr30k-images/5902806140.jpg
# flickr30k-images/5903121771.jpg
# flickr30k-images/59032661.jpg
# flickr30k-images/59032663.jpg
# flickr30k-images/5903521315.jpg
# flickr30k-images/5903528077.jpg
# flickr30k-images/5903545909.jpg
# flickr30k-images/5904096092.jpg
# flickr30k-images/590445887.jpg
# flickr30k-images/5904834587.jpg
# flickr30k-images/5905853755.jpg
# flickr30k-images/5907461517.jpg
# flickr30k-images/5908613029.jpg
# flickr30k-images/59090967.jpg
# flickr30k-images/5911782297.jpg
# flickr30k-images/5914176827.jpg
# flickr30k-images/5914327.jpg
# flickr30k-images/5914778546.jpg
# flickr30k-images/5914789066.jpg
# flickr30k-images/5915534813.jpg
# flickr30k-images/5916878545.jpg
# flickr30k-images/5918675.jpg
# flickr30k-images/5918840.jpg
# flickr30k-images/5919020.jpg
# flickr30k-images/5920741851.jpg
# flickr30k-images/59209034.jpg
# flickr30k-images/5921176217.jpg
# flickr30k-images/5921223189.jpg
# flickr30k-images/5921231203.jpg
# flickr30k-images/5921438594.jpg
# flickr30k-images/5921620687.jpg
# flickr30k-images/5921620999.jpg
# flickr30k-images/5921621723.jpg
# flickr30k-images/5921625277.jpg
# flickr30k-images/5921627317.jpg
# flickr30k-images/5921627737.jpg
# flickr30k-images/5921628407.jpg
# flickr30k-images/5921995766.jpg
# flickr30k-images/5922190538.jpg
# flickr30k-images/5922747284.jpg
# flickr30k-images/5922760648.jpg
# flickr30k-images/5922945248.jpg
# flickr30k-images/5922967014.jpg
# flickr30k-images/5923096321.jpg
# flickr30k-images/5923507305.jpg
# flickr30k-images/5923642022.jpg
# flickr30k-images/5924136287.jpg
# flickr30k-images/5924713518.jpg
# flickr30k-images/592492743.jpg
# flickr30k-images/5925539370.jpg
# flickr30k-images/5925544338.jpg
# flickr30k-images/5925544722.jpg
# flickr30k-images/5925544950.jpg
# flickr30k-images/5925545184.jpg
# flickr30k-images/5925545440.jpg
# flickr30k-images/5925767545.jpg
# flickr30k-images/5926225898.jpg
# flickr30k-images/5926326440.jpg
# flickr30k-images/5927448574.jpg
# flickr30k-images/5929073261.jpg
# flickr30k-images/5929335311.jpg
# flickr30k-images/5929638308.jpg
# flickr30k-images/59303979.jpg
# flickr30k-images/5930681458.jpg
# flickr30k-images/5930769790.jpg
# flickr30k-images/5931039781.jpg
# flickr30k-images/5931115247.jpg
# flickr30k-images/593244695.jpg
# flickr30k-images/5932900326.jpg
# flickr30k-images/5932908042.jpg
# flickr30k-images/593326301.jpg
# flickr30k-images/5936844453.jpg
# flickr30k-images/5938204995.jpg
# flickr30k-images/5938205507.jpg
# flickr30k-images/5938759184.jpg
# flickr30k-images/5941772805.jpg
# flickr30k-images/5941812271.jpg
# flickr30k-images/5942036292.jpg
# flickr30k-images/5942352376.jpg
# flickr30k-images/5942607581.jpg
# flickr30k-images/5942795175.jpg
# flickr30k-images/5943351624.jpg
# flickr30k-images/5944489107.jpg
# flickr30k-images/5944781298.jpg
# flickr30k-images/594582753.jpg
# flickr30k-images/5946823331.jpg
# flickr30k-images/5947536593.jpg
# flickr30k-images/594758693.jpg
# flickr30k-images/5947742521.jpg
# flickr30k-images/5949201274.jpg
# flickr30k-images/5949204053.jpg
# flickr30k-images/5949695639.jpg
# flickr30k-images/5949916228.jpg
# flickr30k-images/5949976408.jpg
# flickr30k-images/5950363786.jpg
# flickr30k-images/595063831.jpg
# flickr30k-images/5954497151.jpg
# flickr30k-images/5954939506.jpg
# flickr30k-images/5955060048.jpg
# flickr30k-images/5955502935.jpg
# flickr30k-images/5957177594.jpg
# flickr30k-images/5958182.jpg
# flickr30k-images/5958376440.jpg
# flickr30k-images/5960638447.jpg
# flickr30k-images/5960769829.jpg
# flickr30k-images/5961400525.jpg
# flickr30k-images/5961657980.jpg
# flickr30k-images/5962276180.jpg
# flickr30k-images/5962278982.jpg
# flickr30k-images/5963915707.jpg
# flickr30k-images/5964395383.jpg
# flickr30k-images/5964699090.jpg
# flickr30k-images/5964803593.jpg
# flickr30k-images/596562699.jpg
# flickr30k-images/5967467152.jpg
# flickr30k-images/5968404576.jpg
# flickr30k-images/5968876205.jpg
# flickr30k-images/5969756753.jpg
# flickr30k-images/5970298083.jpg
# flickr30k-images/5971180169.jpg
# flickr30k-images/5971287030.jpg
# flickr30k-images/5971401832.jpg
# flickr30k-images/5971653128.jpg
# flickr30k-images/5971671598.jpg
# flickr30k-images/597202368.jpg
# flickr30k-images/5972461484.jpg
# flickr30k-images/5972486972.jpg
# flickr30k-images/5972938127.jpg
# flickr30k-images/5972945043.jpg
# flickr30k-images/5973146939.jpg
# flickr30k-images/5973476404.jpg
# flickr30k-images/597543181.jpg
# flickr30k-images/5975778602.jpg
# flickr30k-images/5977277290.jpg
# flickr30k-images/5981613590.jpg
# flickr30k-images/5982829174.jpg
# flickr30k-images/5984974054.jpg
# flickr30k-images/5985691500.jpg
# flickr30k-images/5986222648.jpg
# flickr30k-images/5988551357.jpg
# flickr30k-images/5988551737.jpg
# flickr30k-images/5989225588.jpg
# flickr30k-images/5989324335.jpg
# flickr30k-images/5990016378.jpg
# flickr30k-images/599235529.jpg
# flickr30k-images/599366440.jpg
# flickr30k-images/5995194617.jpg
# flickr30k-images/5995751546.jpg
# flickr30k-images/5995817000.jpg
# flickr30k-images/5996795291.jpg
# flickr30k-images/5999440951.jpg
# flickr30k-images/6000340511.jpg
# flickr30k-images/6002955320.jpg
# flickr30k-images/6003400894.jpg
# flickr30k-images/600353878.jpg
# flickr30k-images/6005527626.jpg
# flickr30k-images/6005939764.jpg
# flickr30k-images/6005955072.jpg
# flickr30k-images/6006191679.jpg
# flickr30k-images/6006578474.jpg
# flickr30k-images/6009022127.jpg
# flickr30k-images/6010457937.jpg
# flickr30k-images/6011146197.jpg
# flickr30k-images/6011731872.jpg
# flickr30k-images/6012139090.jpg
# flickr30k-images/6012829906.jpg
# flickr30k-images/6015520520.jpg
# flickr30k-images/601816185.jpg
# flickr30k-images/6020059753.jpg
# flickr30k-images/6020320520.jpg
# flickr30k-images/6020763700.jpg
# flickr30k-images/6021205363.jpg
# flickr30k-images/6022108522.jpg
# flickr30k-images/6022784716.jpg
# flickr30k-images/6025897064.jpg
# flickr30k-images/602612183.jpg
# flickr30k-images/602723055.jpg
# flickr30k-images/6028997083.jpg
# flickr30k-images/6029705375.jpg
# flickr30k-images/6029710737.jpg
# flickr30k-images/6029713765.jpg
# flickr30k-images/6030269328.jpg
# flickr30k-images/6031795624.jpg
# flickr30k-images/6032152087.jpg
# flickr30k-images/6032301402.jpg
# flickr30k-images/6032303452.jpg
# flickr30k-images/6033533190.jpg
# flickr30k-images/6034056358.jpg
# flickr30k-images/6034227204.jpg
# flickr30k-images/6034236935.jpg
# flickr30k-images/603452271.jpg
# flickr30k-images/60347149.jpg
# flickr30k-images/6036142462.jpg
# flickr30k-images/6037006359.jpg
# flickr30k-images/6038122264.jpg
# flickr30k-images/6039211337.jpg
# flickr30k-images/6039213023.jpg
# flickr30k-images/6039214277.jpg
# flickr30k-images/6040615333.jpg
# flickr30k-images/6041156608.jpg
# flickr30k-images/6041167176.jpg
# flickr30k-images/6041486114.jpg
# flickr30k-images/6042049207.jpg
# flickr30k-images/6042855086.jpg
# flickr30k-images/6043197241.jpg
# flickr30k-images/6043589490.jpg
# flickr30k-images/6044445148.jpg
# flickr30k-images/6044840724.jpg
# flickr30k-images/6046473448.jpg
# flickr30k-images/6046474576.jpg
# flickr30k-images/6049472523.jpg
# flickr30k-images/6050027136.jpg
# flickr30k-images/6052149729.jpg
# flickr30k-images/6053012389.jpg
# flickr30k-images/6053187227.jpg
# flickr30k-images/6053720349.jpg
# flickr30k-images/6054020376.jpg
# flickr30k-images/6054169.jpg
# flickr30k-images/6056271620.jpg
# flickr30k-images/6056788662.jpg
# flickr30k-images/605691297.jpg
# flickr30k-images/6059154572.jpg
# flickr30k-images/6060344876.jpg
# flickr30k-images/60617980.jpg
# flickr30k-images/6063730184.jpg
# flickr30k-images/60644154.jpg
# flickr30k-images/6064872574.jpg
# flickr30k-images/6065327187.jpg
# flickr30k-images/6065883340.jpg
# flickr30k-images/6065938960.jpg
# flickr30k-images/6066197286.jpg
# flickr30k-images/6066636675.jpg
# flickr30k-images/6066650935.jpg
# flickr30k-images/606691813.jpg
# flickr30k-images/6067630216.jpg
# flickr30k-images/6067708481.jpg
# flickr30k-images/6067800722.jpg
# flickr30k-images/6068386039.jpg
# flickr30k-images/6068604099.jpg
# flickr30k-images/6070950788.jpg
# flickr30k-images/6071314957.jpg
# flickr30k-images/6072179885.jpg
# flickr30k-images/607339469.jpg
# flickr30k-images/6073565104.jpg
# flickr30k-images/6073765731.jpg
# flickr30k-images/6074238868.jpg
# flickr30k-images/6074391204.jpg
# flickr30k-images/6074401666.jpg
# flickr30k-images/6074803994.jpg
# flickr30k-images/6075404518.jpg
# flickr30k-images/6075614739.jpg
# flickr30k-images/6075991802.jpg
# flickr30k-images/6077121925.jpg
# flickr30k-images/6077671447.jpg
# flickr30k-images/6077676085.jpg
# flickr30k-images/60779083.jpg
# flickr30k-images/6078212486.jpg
# flickr30k-images/6078216754.jpg
# flickr30k-images/6078286671.jpg
# flickr30k-images/6079294995.jpg
# flickr30k-images/6079467981.jpg
# flickr30k-images/6080521675.jpg
# flickr30k-images/6080747763.jpg
# flickr30k-images/6082212650.jpg
# flickr30k-images/6082254728.jpg
# flickr30k-images/6082535291.jpg
# flickr30k-images/608257195.jpg
# flickr30k-images/6082587848.jpg
# flickr30k-images/6083027696.jpg
# flickr30k-images/6083302879.jpg
# flickr30k-images/608453511.jpg
# flickr30k-images/6084817815.jpg
# flickr30k-images/6085363550.jpg
# flickr30k-images/6086510173.jpg
# flickr30k-images/6086876085.jpg
# flickr30k-images/6087966524.jpg
# flickr30k-images/6089556280.jpg
# flickr30k-images/6090223025.jpg
# flickr30k-images/6090766940.jpg
# flickr30k-images/60908622.jpg
# flickr30k-images/6091899771.jpg
# flickr30k-images/609358708.jpg
# flickr30k-images/6094112851.jpg
# flickr30k-images/6094363151.jpg
# flickr30k-images/6094672224.jpg
# flickr30k-images/6094931376.jpg
# flickr30k-images/609681901.jpg
# flickr30k-images/6098279409.jpg
# flickr30k-images/6098659697.jpg
# flickr30k-images/6098995969.jpg
# flickr30k-images/6099093979.jpg
# flickr30k-images/6099913481.jpg
# flickr30k-images/6100004189.jpg
# flickr30k-images/6100315.jpg
# flickr30k-images/6101818492.jpg
# flickr30k-images/6104320982.jpg
# flickr30k-images/6104468585.jpg
# flickr30k-images/610590753.jpg
# flickr30k-images/6105998656.jpg
# flickr30k-images/610802443.jpg
# flickr30k-images/610825957.jpg
# flickr30k-images/6108282669.jpg
# flickr30k-images/610841649.jpg
# flickr30k-images/6110024306.jpg
# flickr30k-images/6110845331.jpg
# flickr30k-images/611301340.jpg
# flickr30k-images/611349356.jpg
# flickr30k-images/6113672400.jpg
# flickr30k-images/6116491209.jpg
# flickr30k-images/6118635937.jpg
# flickr30k-images/611910909.jpg
# flickr30k-images/61191899.jpg
# flickr30k-images/61206655.jpg
# flickr30k-images/61209225.jpg
# flickr30k-images/6121112512.jpg
# flickr30k-images/6121757226.jpg
# flickr30k-images/6123457215.jpg
# flickr30k-images/6126382452.jpg
# flickr30k-images/6126520718.jpg
# flickr30k-images/6126962700.jpg
# flickr30k-images/6129630643.jpg
# flickr30k-images/6129698446.jpg
# flickr30k-images/613030608.jpg
# flickr30k-images/6131156900.jpg
# flickr30k-images/613373175.jpg
# flickr30k-images/6135433028.jpg
# flickr30k-images/6135582891.jpg
# flickr30k-images/6135587407.jpg
# flickr30k-images/6136127574.jpg
# flickr30k-images/61372129.jpg
# flickr30k-images/61374980.jpg
# flickr30k-images/6137946415.jpg
# flickr30k-images/613900608.jpg
# flickr30k-images/6139525250.jpg
# flickr30k-images/6140511870.jpg
# flickr30k-images/6141144133.jpg
# flickr30k-images/6141300695.jpg
# flickr30k-images/6141381971.jpg
# flickr30k-images/6141695796.jpg
# flickr30k-images/6141698120.jpg
# flickr30k-images/6141966747.jpg
# flickr30k-images/6141981912.jpg
# flickr30k-images/6142026295.jpg
# flickr30k-images/6142033763.jpg
# flickr30k-images/6142334811.jpg
# flickr30k-images/6142467963.jpg
# flickr30k-images/6143908469.jpg
# flickr30k-images/6143969605.jpg
# flickr30k-images/6144531701.jpg
# flickr30k-images/6144893265.jpg
# flickr30k-images/61454211.jpg
# flickr30k-images/614590294.jpg
# flickr30k-images/614590366.jpg
# flickr30k-images/6146405403.jpg
# flickr30k-images/6147060999.jpg
# flickr30k-images/6147066205.jpg
# flickr30k-images/6147735412.jpg
# flickr30k-images/6148543097.jpg
# flickr30k-images/6148905552.jpg
# flickr30k-images/615025092.jpg
# flickr30k-images/6150843883.jpg
# flickr30k-images/6151897522.jpg
# flickr30k-images/6152090114.jpg
# flickr30k-images/6152180229.jpg
# flickr30k-images/6152219961.jpg
# flickr30k-images/6153400574.jpg
# flickr30k-images/6154676236.jpg
# flickr30k-images/6155176.jpg
# flickr30k-images/6155570605.jpg
# flickr30k-images/6155571589.jpg
# flickr30k-images/6155718367.jpg
# flickr30k-images/6156276992.jpg
# flickr30k-images/6156372684.jpg
# flickr30k-images/6156416718.jpg
# flickr30k-images/6157355105.jpg
# flickr30k-images/6157403653.jpg
# flickr30k-images/6157574915.jpg
# flickr30k-images/6157897194.jpg
# flickr30k-images/6158752589.jpg
# flickr30k-images/6158943082.jpg
# flickr30k-images/615916000.jpg
# flickr30k-images/615927423.jpg
# flickr30k-images/6159485039.jpg
# flickr30k-images/6160193920.jpg
# flickr30k-images/6160319160.jpg
# flickr30k-images/616045808.jpg
# flickr30k-images/6161478369.jpg
# flickr30k-images/6161755456.jpg
# flickr30k-images/616177206.jpg
# flickr30k-images/6162015348.jpg
# flickr30k-images/616237861.jpg
# flickr30k-images/6164245162.jpg
# flickr30k-images/6164609837.jpg
# flickr30k-images/6164855846.jpg
# flickr30k-images/616564448.jpg
# flickr30k-images/6166659366.jpg
# flickr30k-images/6166766593.jpg
# flickr30k-images/6167267993.jpg
# flickr30k-images/6167479966.jpg
# flickr30k-images/6167481552.jpg
# flickr30k-images/6167795092.jpg
# flickr30k-images/6168223686.jpg
# flickr30k-images/617038406.jpg
# flickr30k-images/6170429974.jpg
# flickr30k-images/6171694399.jpg
# flickr30k-images/6171705161.jpg
# flickr30k-images/6174401215.jpg
# flickr30k-images/61745811.jpg
# flickr30k-images/6175408029.jpg
# flickr30k-images/6175830478.jpg
# flickr30k-images/617685123.jpg
# flickr30k-images/6177158223.jpg
# flickr30k-images/6177258327.jpg
# flickr30k-images/6177260197.jpg
# flickr30k-images/617782839.jpg
# flickr30k-images/6178585333.jpg
# flickr30k-images/6178836593.jpg
# flickr30k-images/6178994097.jpg
# flickr30k-images/6178998938.jpg
# flickr30k-images/6179361394.jpg
# flickr30k-images/6179362236.jpg
# flickr30k-images/6179396322.jpg
# flickr30k-images/6179612438.jpg
# flickr30k-images/617999370.jpg
# flickr30k-images/6180215411.jpg
# flickr30k-images/6180681091.jpg
# flickr30k-images/6180807938.jpg
# flickr30k-images/6181621171.jpg
# flickr30k-images/6181931777.jpg
# flickr30k-images/618292739.jpg
# flickr30k-images/6184114561.jpg
# flickr30k-images/6184270681.jpg
# flickr30k-images/6185163733.jpg
# flickr30k-images/6185849002.jpg
# flickr30k-images/6185957886.jpg
# flickr30k-images/6186146093.jpg
# flickr30k-images/6187182607.jpg
# flickr30k-images/6187182623.jpg
# flickr30k-images/6187191468.jpg
# flickr30k-images/618735339.jpg
# flickr30k-images/618771382.jpg
# flickr30k-images/6187926673.jpg
# flickr30k-images/618797331.jpg
# flickr30k-images/6188266707.jpg
# flickr30k-images/6188475741.jpg
# flickr30k-images/6188479019.jpg
# flickr30k-images/6188752802.jpg
# flickr30k-images/6188774172.jpg
# flickr30k-images/6188880632.jpg
# flickr30k-images/6188883048.jpg
# flickr30k-images/6189180318.jpg
# flickr30k-images/6189950649.jpg
# flickr30k-images/6190299977.jpg
# flickr30k-images/6190349317.jpg
# flickr30k-images/6191212927.jpg
# flickr30k-images/6191516871.jpg
# flickr30k-images/6191612418.jpg
# flickr30k-images/619169586.jpg
# flickr30k-images/6191733410.jpg
# flickr30k-images/6192034820.jpg
# flickr30k-images/6193474428.jpg
# flickr30k-images/6194677011.jpg
# flickr30k-images/6194740899.jpg
# flickr30k-images/6195608205.jpg
# flickr30k-images/6195995631.jpg
# flickr30k-images/6196180784.jpg
# flickr30k-images/6196508338.jpg
# flickr30k-images/6198220750.jpg
# ...
# flickr30k-images/8227381437.jpg
# flickr30k-images/822836318.jpg
# flickr30k-images/8231853822.jpg
# flickr30k-images/8233488463.jpg
# flickr30k-images/823425327.jpg
# flickr30k-images/8234387593.jpg
# flickr30k-images/823498977.jpg
# flickr30k-images/8235903055.jpg
# flickr30k-images/8236263716.jpg
# flickr30k-images/823675317.jpg
# flickr30k-images/823696468.jpg
# flickr30k-images/823697026.jpg
# flickr30k-images/823697339.jpg
# flickr30k-images/8237132978.jpg
# flickr30k-images/8237901726.jpg
# flickr30k-images/8238928026.jpg
# flickr30k-images/8239100625.jpg
# flickr30k-images/8239102645.jpg
# flickr30k-images/8240968816.jpg
# flickr30k-images/824123145.jpg
# flickr30k-images/82414149.jpg
# flickr30k-images/8242408919.jpg
# flickr30k-images/8243477528.jpg
# flickr30k-images/8245313425.jpg
# flickr30k-images/8245366095.jpg
# flickr30k-images/8247042603.jpg
# flickr30k-images/824782868.jpg
# flickr30k-images/8248428448.jpg
# flickr30k-images/824923476.jpg
# flickr30k-images/82506738.jpg
# flickr30k-images/8251170369.jpg
# flickr30k-images/8251604257.jpg
# flickr30k-images/825918657.jpg
# flickr30k-images/826419814.jpg
# flickr30k-images/82675922.jpg
# flickr30k-images/82676249.jpg
# flickr30k-images/82676766.jpg
# flickr30k-images/82679822.jpg
# flickr30k-images/82679989.jpg
# flickr30k-images/82680989.jpg
# flickr30k-images/82681058.jpg
# flickr30k-images/826919541.jpg
# flickr30k-images/827941668.jpg
# flickr30k-images/82945847.jpg
# flickr30k-images/829798661.jpg
# flickr30k-images/83001714.jpg
# flickr30k-images/830745339.jpg
# flickr30k-images/831025550.jpg
# flickr30k-images/831655324.jpg
# flickr30k-images/83191345.jpg
# flickr30k-images/832128857.jpg
# flickr30k-images/83292701.jpg
# flickr30k-images/833319080.jpg
# flickr30k-images/83334342.jpg
# flickr30k-images/833459429.jpg
# flickr30k-images/83434923.jpg
# flickr30k-images/83440865.jpg
# flickr30k-images/83457315.jpg
# flickr30k-images/83482568.jpg
# flickr30k-images/83493458.jpg
# flickr30k-images/835415474.jpg
# flickr30k-images/835606668.jpg
# flickr30k-images/83575794.jpg
# flickr30k-images/836768303.jpg
# flickr30k-images/836828001.jpg
# flickr30k-images/83701972.jpg
# flickr30k-images/83755390.jpg
# flickr30k-images/8378599.jpg
# flickr30k-images/837893113.jpg
# flickr30k-images/837919879.jpg
# flickr30k-images/838074897.jpg
# flickr30k-images/839295615.jpg
# flickr30k-images/840202638.jpg
# flickr30k-images/8404753.jpg
# flickr30k-images/841397013.jpg
# flickr30k-images/842263436.jpg
# flickr30k-images/84291062.jpg
# flickr30k-images/842960985.jpg
# flickr30k-images/842961005.jpg
# flickr30k-images/843218288.jpg
# flickr30k-images/843616798.jpg
# flickr30k-images/843843809.jpg
# flickr30k-images/844258711.jpg
# flickr30k-images/8443156.jpg
# flickr30k-images/845047334.jpg
# flickr30k-images/84507882.jpg
# flickr30k-images/84509412.jpg
# flickr30k-images/84509831.jpg
# flickr30k-images/84514007.jpg
# flickr30k-images/8454235.jpg
# flickr30k-images/845623658.jpg
# flickr30k-images/845940422.jpg
# flickr30k-images/846070499.jpg
# flickr30k-images/846085364.jpg
# flickr30k-images/846516819.jpg
# flickr30k-images/84713990.jpg
# flickr30k-images/847782643.jpg
# flickr30k-images/848007330.jpg
# flickr30k-images/848180689.jpg
# flickr30k-images/84819693.jpg
# flickr30k-images/84824317.jpg
# flickr30k-images/848293676.jpg
# flickr30k-images/84864687.jpg
# flickr30k-images/84927810.jpg
# flickr30k-images/84962837.jpg
# flickr30k-images/85014310.jpg
# flickr30k-images/85139806.jpg
# flickr30k-images/851566221.jpg
# flickr30k-images/852427632.jpg
# flickr30k-images/852469220.jpg
# flickr30k-images/85306246.jpg
# flickr30k-images/85306247.jpg
# flickr30k-images/85306249.jpg
# flickr30k-images/85306254.jpg
# flickr30k-images/85318252.jpg
# flickr30k-images/85318261.jpg
# flickr30k-images/85326165.jpg
# flickr30k-images/854333409.jpg
# flickr30k-images/854623746.jpg
# flickr30k-images/854749.jpg
# flickr30k-images/854848076.jpg
# flickr30k-images/85519095.jpg
# flickr30k-images/855430954.jpg
# flickr30k-images/85574732.jpg
# flickr30k-images/85600252.jpg
# flickr30k-images/85676478.jpg
# flickr30k-images/856985136.jpg
# flickr30k-images/85707684.jpg
# flickr30k-images/85707689.jpg
# flickr30k-images/857914283.jpg
# flickr30k-images/858747984.jpg
# flickr30k-images/859620561.jpg
# flickr30k-images/860060733.jpg
# flickr30k-images/8601145.jpg
# flickr30k-images/860271719.jpg
# flickr30k-images/860526919.jpg
# flickr30k-images/860840598.jpg
# flickr30k-images/860928274.jpg
# flickr30k-images/86109322.jpg
# flickr30k-images/86109631.jpg
# flickr30k-images/86112634.jpg
# flickr30k-images/86112682.jpg
# flickr30k-images/86112730.jpg
# flickr30k-images/86112808.jpg
# flickr30k-images/86112875.jpg
# flickr30k-images/86112925.jpg
# flickr30k-images/86112958.jpg
# flickr30k-images/86120374.jpg
# flickr30k-images/86120427.jpg
# flickr30k-images/86120479.jpg
# flickr30k-images/86120569.jpg
# flickr30k-images/86120657.jpg
# flickr30k-images/86120682.jpg
# flickr30k-images/86120741.jpg
# flickr30k-images/86120813.jpg
# flickr30k-images/86120845.jpg
# flickr30k-images/86120876.jpg
# flickr30k-images/86120978.jpg
# flickr30k-images/86124605.jpg
# flickr30k-images/86127083.jpg
# flickr30k-images/86131617.jpg
# flickr30k-images/86131989.jpg
# flickr30k-images/86132021.jpg
# flickr30k-images/861608773.jpg
# flickr30k-images/861661418.jpg
# flickr30k-images/861795382.jpg
# flickr30k-images/86198383.jpg
# flickr30k-images/862054277.jpg
# flickr30k-images/862156271.jpg
# flickr30k-images/862177617.jpg
# flickr30k-images/862187579.jpg
# flickr30k-images/862511637.jpg
# flickr30k-images/862560775.jpg
# flickr30k-images/86256551.jpg
# flickr30k-images/862683343.jpg
# flickr30k-images/86288449.jpg
# flickr30k-images/86289690.jpg
# flickr30k-images/86289696.jpg
# flickr30k-images/86289724.jpg
# flickr30k-images/863036078.jpg
# flickr30k-images/86341446.jpg
# flickr30k-images/86343902.jpg
# flickr30k-images/86350713.jpg
# flickr30k-images/863901193.jpg
# flickr30k-images/863902615.jpg
# flickr30k-images/86412576.jpg
# flickr30k-images/864290968.jpg
# flickr30k-images/864546649.jpg
# flickr30k-images/864827397.jpg
# flickr30k-images/86486817.jpg
# flickr30k-images/86497011.jpg
# flickr30k-images/865004756.jpg
# flickr30k-images/86542183.jpg
# flickr30k-images/86549526.jpg
# flickr30k-images/865573132.jpg
# flickr30k-images/865789346.jpg
# flickr30k-images/8664920.jpg
# flickr30k-images/8664922.jpg
# flickr30k-images/866841633.jpg
# flickr30k-images/867204263.jpg
# flickr30k-images/86729182.jpg
# flickr30k-images/86734276.jpg
# flickr30k-images/867599993.jpg
# flickr30k-images/86800579.jpg
# flickr30k-images/8680922.jpg
# flickr30k-images/8684718.jpg
# flickr30k-images/868984478.jpg
# flickr30k-images/86901941.jpg
# flickr30k-images/86987116.jpg
# flickr30k-images/870186901.jpg
# flickr30k-images/870367466.jpg
# flickr30k-images/870386962.jpg
# flickr30k-images/870710405.jpg
# flickr30k-images/87119046.jpg
# flickr30k-images/871290646.jpg
# flickr30k-images/871290666.jpg
# flickr30k-images/871909953.jpg
# flickr30k-images/872135364.jpg
# flickr30k-images/872512911.jpg
# flickr30k-images/872615435.jpg
# flickr30k-images/872622575.jpg
# flickr30k-images/873633312.jpg
# flickr30k-images/873650807.jpg
# flickr30k-images/873862583.jpg
# flickr30k-images/87388323.jpg
# flickr30k-images/873933926.jpg
# flickr30k-images/874665322.jpg
# flickr30k-images/874736612.jpg
# flickr30k-images/875731481.jpg
# flickr30k-images/8757787.jpg
# flickr30k-images/876493846.jpg
# flickr30k-images/876964091.jpg
# flickr30k-images/87718618.jpg
# flickr30k-images/87761964.jpg
# flickr30k-images/878278559.jpg
# flickr30k-images/878355466.jpg
# flickr30k-images/878758390.jpg
# flickr30k-images/87877338.jpg
# flickr30k-images/879043160.jpg
# flickr30k-images/87938334.jpg
# flickr30k-images/87940007.jpg
# flickr30k-images/880220939.jpg
# flickr30k-images/880663417.jpg
# flickr30k-images/880663887.jpg
# flickr30k-images/88127430.jpg
# flickr30k-images/881336.jpg
# flickr30k-images/881383469.jpg
# flickr30k-images/881443395.jpg
# flickr30k-images/881725588.jpg
# flickr30k-images/882048099.jpg
# flickr30k-images/88279365.jpg
# flickr30k-images/883040210.jpg
# flickr30k-images/8832804.jpg
# flickr30k-images/88486769.jpg
# flickr30k-images/88486961.jpg
# flickr30k-images/88488944.jpg
# flickr30k-images/8849890.jpg
# flickr30k-images/8859482.jpg
# flickr30k-images/887108308.jpg
# flickr30k-images/88767910.jpg
# flickr30k-images/8876934.jpg
# flickr30k-images/888244173.jpg
# flickr30k-images/888425986.jpg
# flickr30k-images/888517718.jpg
# flickr30k-images/889751330.jpg
# flickr30k-images/890734502.jpg
# flickr30k-images/89202781.jpg
# flickr30k-images/892340814.jpg
# flickr30k-images/89245315.jpg
# flickr30k-images/89253626.jpg
# flickr30k-images/892870649.jpg
# flickr30k-images/89332423.jpg
# flickr30k-images/89353191.jpg
# flickr30k-images/893808757.jpg
# flickr30k-images/89404014.jpg
# flickr30k-images/89407459.jpg
# flickr30k-images/894928353.jpg
# flickr30k-images/894964960.jpg
# flickr30k-images/89505897.jpg
# flickr30k-images/895359811.jpg
# flickr30k-images/895502702.jpg
# flickr30k-images/897406883.jpg
# flickr30k-images/897621891.jpg
# flickr30k-images/89779839.jpg
# flickr30k-images/89787769.jpg
# flickr30k-images/8990627.jpg
# flickr30k-images/899079053.jpg
# flickr30k-images/899810584.jpg
# flickr30k-images/90011335.jpg
# flickr30k-images/900144365.jpg
# flickr30k-images/90044984.jpg
# flickr30k-images/900557881.jpg
# flickr30k-images/90093157.jpg
# flickr30k-images/901027462.jpg
# flickr30k-images/90123355.jpg
# flickr30k-images/90168112.jpg
# flickr30k-images/901763909.jpg
# flickr30k-images/9035232.jpg
# flickr30k-images/90358839.jpg
# flickr30k-images/904404695.jpg
# flickr30k-images/905022127.jpg
# flickr30k-images/905355838.jpg
# flickr30k-images/906991263.jpg
# flickr30k-images/908636680.jpg
# flickr30k-images/909191414.jpg
# flickr30k-images/909808296.jpg
# flickr30k-images/91083825.jpg
# flickr30k-images/911527312.jpg
# flickr30k-images/911795495.jpg
# flickr30k-images/912382266.jpg
# flickr30k-images/912402498.jpg
# flickr30k-images/91251257.jpg
# flickr30k-images/91365036.jpg
# flickr30k-images/915300855.jpg
# flickr30k-images/916624251.jpg
# flickr30k-images/917574521.jpg
# flickr30k-images/91852718.jpg
# flickr30k-images/918545497.jpg
# flickr30k-images/91875542.jpg
# flickr30k-images/918886676.jpg
# flickr30k-images/91972799.jpg
# flickr30k-images/921190481.jpg
# flickr30k-images/92246314.jpg
# flickr30k-images/92289076.jpg
# flickr30k-images/923550133.jpg
# flickr30k-images/92413203.jpg
# flickr30k-images/92497263.jpg
# flickr30k-images/925491651.jpg
# flickr30k-images/92679312.jpg
# flickr30k-images/9268793.jpg
# flickr30k-images/92732320.jpg
# flickr30k-images/927420680.jpg
# flickr30k-images/929679367.jpg
# flickr30k-images/930126921.jpg
# flickr30k-images/930748509.jpg
# flickr30k-images/931028778.jpg
# flickr30k-images/931156700.jpg
# flickr30k-images/9324151.jpg
# flickr30k-images/93270842.jpg
# flickr30k-images/93307139.jpg
# flickr30k-images/93311089.jpg
# flickr30k-images/933118213.jpg
# flickr30k-images/934028208.jpg
# flickr30k-images/93406137.jpg
# flickr30k-images/934375844.jpg
# flickr30k-images/93447586.jpg
# flickr30k-images/937559727.jpg
# flickr30k-images/938012664.jpg
# flickr30k-images/938162709.jpg
# flickr30k-images/938661426.jpg
# flickr30k-images/93922153.jpg
# flickr30k-images/94024624.jpg
# flickr30k-images/94062798.jpg
# flickr30k-images/940973925.jpg
# flickr30k-images/941641803.jpg
# flickr30k-images/94183012.jpg
# flickr30k-images/94232465.jpg
# flickr30k-images/942399470.jpg
# flickr30k-images/9426826.jpg
# flickr30k-images/942900552.jpg
# flickr30k-images/944374205.jpg
# flickr30k-images/944424269.jpg
# flickr30k-images/94472195.jpg
# flickr30k-images/944788251.jpg
# flickr30k-images/944860697.jpg
# flickr30k-images/945509052.jpg
# flickr30k-images/945555443.jpg
# flickr30k-images/946051430.jpg
# flickr30k-images/946102063.jpg
# flickr30k-images/947664583.jpg
# flickr30k-images/947969010.jpg
# flickr30k-images/948196883.jpg
# flickr30k-images/94987177.jpg
# flickr30k-images/94989565.jpg
# flickr30k-images/95017523.jpg
# flickr30k-images/95021246.jpg
# flickr30k-images/95021247.jpg
# flickr30k-images/950273886.jpg
# flickr30k-images/950411653.jpg
# flickr30k-images/95081415.jpg
# flickr30k-images/95081629.jpg
# flickr30k-images/95151149.jpg
# flickr30k-images/952171414.jpg
# flickr30k-images/952262215.jpg
# flickr30k-images/952352291.jpg
# flickr30k-images/952389673.jpg
# flickr30k-images/952457689.jpg
# flickr30k-images/953036866.jpg
# flickr30k-images/953120250.jpg
# flickr30k-images/953941506.jpg
# flickr30k-images/954987350.jpg
# flickr30k-images/9556225.jpg
# flickr30k-images/9556226.jpg
# flickr30k-images/956164675.jpg
# flickr30k-images/957129624.jpg
# flickr30k-images/957230475.jpg
# flickr30k-images/95728660.jpg
# flickr30k-images/95728664.jpg
# flickr30k-images/95734035.jpg
# flickr30k-images/95734036.jpg
# flickr30k-images/95734038.jpg
# flickr30k-images/957585444.jpg
# flickr30k-images/95758790.jpg
# flickr30k-images/957682378.jpg
# flickr30k-images/95783195.jpg
# flickr30k-images/95795877.jpg
# flickr30k-images/958166873.jpg
# flickr30k-images/958317706.jpg
# flickr30k-images/958326692.jpg
# flickr30k-images/95903273.jpg
# flickr30k-images/9600569.jpg
# flickr30k-images/960092.jpg
# flickr30k-images/96022995.jpg
# flickr30k-images/96051221.jpg
# flickr30k-images/96056569.jpg
# flickr30k-images/96059112.jpg
# flickr30k-images/96113759.jpg
# flickr30k-images/961189263.jpg
# flickr30k-images/961220478.jpg
# flickr30k-images/961611340.jpg
# flickr30k-images/961664774.jpg
# flickr30k-images/963730324.jpg
# flickr30k-images/9637989.jpg
# flickr30k-images/96395587.jpg
# flickr30k-images/96399948.jpg
# flickr30k-images/964197865.jpg
# flickr30k-images/96420612.jpg
# flickr30k-images/96421540.jpg
# flickr30k-images/964287333.jpg
# flickr30k-images/96461750.jpg
# flickr30k-images/964871444.jpg
# flickr30k-images/965444691.jpg
# flickr30k-images/96669857.jpg
# flickr30k-images/96692346.jpg
# flickr30k-images/966971031.jpg
# flickr30k-images/967719295.jpg
# flickr30k-images/968081289.jpg
# flickr30k-images/96828131.jpg
# flickr30k-images/969483211.jpg
# flickr30k-images/969655512.jpg
# flickr30k-images/96973080.jpg
# flickr30k-images/969779007.jpg
# flickr30k-images/96978713.jpg
# flickr30k-images/96985174.jpg
# flickr30k-images/970641406.jpg
# flickr30k-images/970958470.jpg
# flickr30k-images/97105139.jpg
# flickr30k-images/97131520.jpg
# flickr30k-images/97138308.jpg
# flickr30k-images/97138973.jpg
# flickr30k-images/97162852.jpg
# flickr30k-images/97233789.jpg
# flickr30k-images/97234558.jpg
# flickr30k-images/972381743.jpg
# flickr30k-images/9726060.jpg
# flickr30k-images/973353650.jpg
# flickr30k-images/973827791.jpg
# flickr30k-images/97406261.jpg
# flickr30k-images/974924582.jpg
# flickr30k-images/97495047.jpg
# flickr30k-images/975131015.jpg
# flickr30k-images/97577988.jpg
# flickr30k-images/976392326.jpg
# flickr30k-images/976414321.jpg
# flickr30k-images/976581518.jpg
# flickr30k-images/976639041.jpg
# flickr30k-images/97731718.jpg
# flickr30k-images/977365989.jpg
# flickr30k-images/97748313.jpg
# flickr30k-images/977856234.jpg
# flickr30k-images/977898311.jpg
# flickr30k-images/978028673.jpg
# flickr30k-images/97825959.jpg
# flickr30k-images/978580450.jpg
# flickr30k-images/979201222.jpg
# flickr30k-images/979383193.jpg
# flickr30k-images/97971267.jpg
# flickr30k-images/980090465.jpg
# flickr30k-images/98023274.jpg
# flickr30k-images/980615147.jpg
# flickr30k-images/981727078.jpg
# flickr30k-images/982013557.jpg
# flickr30k-images/98208372.jpg
# flickr30k-images/98235403.jpg
# flickr30k-images/983396629.jpg
# flickr30k-images/98377566.jpg
# flickr30k-images/984092829.jpg
# flickr30k-images/98415168.jpg
# flickr30k-images/98438433.jpg
# flickr30k-images/98492339.jpg
# flickr30k-images/984950.jpg
# flickr30k-images/985067019.jpg
# flickr30k-images/98557260.jpg
# flickr30k-images/985982384.jpg
# flickr30k-images/986127455.jpg
# flickr30k-images/986440271.jpg
# flickr30k-images/987442144.jpg
# flickr30k-images/98756067.jpg
# flickr30k-images/98756125.jpg
# flickr30k-images/98773047.jpg
# flickr30k-images/987907964.jpg
# flickr30k-images/98817947.jpg
# flickr30k-images/98885561.jpg
# flickr30k-images/98944492.jpg
# flickr30k-images/989754491.jpg
# flickr30k-images/989851184.jpg
# flickr30k-images/990890291.jpg
# flickr30k-images/991459749.jpg
# flickr30k-images/991459823.jpg
# flickr30k-images/99171998.jpg
# flickr30k-images/991971859.jpg
# flickr30k-images/99458430.jpg
# flickr30k-images/9950858.jpg
# flickr30k-images/9950913.jpg
# flickr30k-images/996089206.jpg
# flickr30k-images/996712323.jpg
# flickr30k-images/99679241.jpg
# flickr30k-images/996962407.jpg
# flickr30k-images/997338199.jpg
# flickr30k-images/997722733.jpg
# flickr30k-images/997876722.jpg
# flickr30k-images/99804383.jpg
# flickr30k-images/998845445.jpg
# flickr30k-images/readme.txt

# %%
training_data = Flickr30k('flickr30k-images', 'results_20130124.token')

# %%
class Vocabulary(object):
    """Simple vocabulary wrapper."""
    def __init__(self):
        self.word2idx = {}
        self.idx2word = {}
        self.idx = 0
        self.all_words = []

    def add_word(self, word):
        if not word in self.word2idx:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1
            self.all_words.append(word)
            
    def __call__(self, word):
        if not word in self.word2idx:
            return self.word2idx['<unk>']
        return self.word2idx[word]

    def __len__(self):
        return len(self.word2idx)

    def get_id(self, w):
        return self.word2idx[w]

    def encode_seq(self, l):
        return [self.word2idx[i] if i in self.word2idx else self.word2idx['<unk>'] for i in l]

    def get_token(self, idx):
        return self.idx2word[idx]

    def decode_seq(self, l):
        return [self.idx2word[i] for i in l]

# %%
def get_splits(filepath = 'flickr30k-images', size = 256, seed = 2020):
    np.random.seed(seed)
    train_set = set()
    val_set = set()
    test_set = set()
    
    for filename in tqdm(os.listdir(filepath)):
        if filename[-3:] == 'jpg':
            img = np.array(Image.open(os.path.join(filepath, filename)))
            if img.shape[0] >= size and img.shape[1] >= size:
                selector = np.random.multinomial(size=1, n=1, pvals = [0.8, 0.1, 0.1])
                if selector[0][0] == 1:
                    train_set.add(filename)
                elif selector[0][1] == 1: 
                    val_set.add(filename)
                else:
                    test_set.add(filename)
            
    pickle.dump(train_set,open('train_set.p', 'wb'))
    pickle.dump(val_set,open('val_set.p', 'wb'))
    pickle.dump(test_set,open('test_set.p', 'wb'))

get_splits()
# Out:
# 100%|██████████| 31784/31784 [03:02<00:00, 173.88it/s]

# %%
def build_vocab(ann_file = 'results_20130124.token', threshold = 3):
    """Build a simple vocabulary wrapper."""
    punc_set = set([',',';',':','.','?','!','(',')','``','"'])
    counter = Counter()
    caption_list = []
    split = pickle.load(open('train_set.p', 'rb'))
    ann_file = os.path.expanduser(ann_file)
    with open(ann_file) as fh:
        for line in fh:
            img, caption = line.strip().split('\t')
            if img[:-2] in split:
                caption_list.append(caption)
    for caption in tqdm(caption_list):
        tokens = nltk.tokenize.word_tokenize(caption.lower())
        tokens = [elem for elem in tokens if elem not in punc_set] 
        counter.update(tokens)

    words = [word for word, cnt in counter.items() if cnt >= threshold] 

    vocab = Vocabulary()
    vocab.add_word('<pad>')
    vocab.add_word('<start>')
    vocab.add_word('<end>')
    vocab.add_word('<unk>')
    vocab.add_word('<break>')

    for i, word in enumerate(words):
        vocab.add_word(word)
    return vocab

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
vocab = build_vocab()
pickle.dump(vocab,open('vocab.p', 'wb'))
# Out:
# 100%|██████████| 126330/126330 [00:12<00:00, 9930.98it/s]

# %%
class Custom_Flickr30k(VisionDataset):

    def __init__(self, root, ann_file, vocabulary, train=True, transform=None, target_transform=None, test=False):
        super(Custom_Flickr30k, self).__init__(root, transform=transform, target_transform=target_transform)
        self.ann_file = os.path.expanduser(ann_file)
        self.train = train
        self.test = test
        self.annotations = defaultdict(list)
        self.punc_set = set([',',';',':','.','?','!','(',')'])
        
        if self.train:
            split = pickle.load(open('train_set.p', 'rb'))
            idx=0
            with open(self.ann_file) as fh:
                for line in fh:
                    img_id, caption = line.strip().split('\t')
                    img = img_id[:-2]
                    if img in split:
                        self.annotations[idx].extend([img,caption])
                        idx += 1
            self.ids = np.arange(idx-1)
        elif self.test:
            split = pickle.load(open('test_set.p', 'rb'))
            idx=0
            with open(self.ann_file) as fh:
                for line in fh:
                    img_id, caption = line.strip().split('\t')
                    img = img_id[:-2]
                    if img in split:
                        self.annotations[idx].extend([img,caption])
                        idx += 1
            self.ids = np.arange(idx-1)
        else:
            split = pickle.load(open('val_set.p', 'rb'))
            idx = -1
            last_image = ''
            with open(self.ann_file) as fh:
                for line in fh:
                    img_id, caption = line.strip().split('\t')
                    img = img_id[:-2]
                    if img in split:
                        if img != last_image:
                            idx += 1
                            last_image = img
                            self.annotations[idx].append(img)
                            self.annotations[idx].append([caption])
                        else:
                            self.annotations[idx][1].append(caption)
            self.ids = np.arange(idx)

    def __getitem__(self, index):
        
        instance = self.annotations[index]
        
        img_id = instance[0]
        caption = instance[1]
        
        filename = os.path.join(self.root, img_id)
        img = Image.open(filename).convert('RGB')
        if self.transform is not None:
            img = self.transform(img)
        
        if self.train or self.test:

            tokens = nltk.tokenize.word_tokenize(str(caption).lower())
            caption = []
            caption.append(vocab('<start>'))
            caption.extend([vocab(token) for token in tokens if token not in self.punc_set])
            caption.append(vocab('<end>'))
            target = torch.Tensor(caption)
            
        else:
            target = []
            for item in caption:
                tokens = nltk.tokenize.word_tokenize(str(item).lower())
                target.extend([vocab(token) for token in tokens if token not in self.punc_set])
                target.append(vocab('<break>'))
            
            target = torch.Tensor(target[:-1])

        return img, target


    def __len__(self):
        return len(self.ids)

# %%
def collate_fn(data):

    data.sort(key=lambda x: len(x[1]), reverse=True)
    images, captions = zip(*data)

    images = torch.stack(images, 0)

    lengths = [len(cap) for cap in captions]
    targets = torch.zeros(len(captions), max(lengths)).long()
    for i, cap in enumerate(captions):
        end = lengths[i]
        targets[i, :end] = cap[:end]        
    return images, targets, lengths

# %%
batch_size = 128
num_workers = 4
crop_size = 256
transform = transforms.Compose([
            transforms.RandomCrop(crop_size),
            transforms.RandomHorizontalFlip(), 
            transforms.ToTensor(), 
            transforms.Normalize((0.444, 0.421, 0.385), 
                                 (0.285, 0.277, 0.286))])

# %%
flickr_data = Custom_Flickr30k('flickr30k-images', 'results_20130124.token', vocab, transform=transform)
data_loader = torch.utils.data.DataLoader(dataset=flickr_data, 
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=num_workers,
                                          collate_fn=collate_fn)

# %%
class SimpleEncoderCNN(nn.Module):
    def __init__(self, embed_size, fine_tune=False):
        super(SimpleEncoderCNN, self).__init__()
        self.fine_tune = fine_tune
        resnet = models.resnet50(pretrained=True)
        modules = list(resnet.children())[:-1]      
        self.resnet = nn.Sequential(*modules)
        self.linear = nn.Linear(resnet.fc.in_features, embed_size)
        self.bn = nn.BatchNorm1d(embed_size, momentum=0.1)

    def forward(self, images):
        if self.fine_tune:
            features = self.resnet(images)
        else:
            with torch.no_grad():
                features = self.resnet(images)
        features = features.reshape(features.size(0), -1)
        features = self.bn(self.linear(features))
        return features

# %%
class SimpleDecoderRNN(nn.Module):
    def __init__(self, embed_size, hidden_size, vocab_size, num_layers):
        super(SimpleDecoderRNN, self).__init__()
        self.embed = nn.Embedding(vocab_size, embed_size)
        self.gru = nn.GRU(embed_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, vocab_size)

    def forward(self, features, captions, lengths):
        embeddings = self.embed(captions)
        embeddings = torch.cat((features.unsqueeze(1), embeddings), 1)
        packed = pack_padded_sequence(embeddings, lengths, batch_first=True)
        hiddens, _ = self.gru(packed)
        outputs = self.linear(hiddens[0])
        return outputs

    def sample(self, features, states=None, max_seq_length=20):
        sampled_ids = []
        inputs = features.unsqueeze(1)
        for i in range(max_seq_length):
            hiddens, states = self.gru(inputs, states)         
            outputs = self.linear(hiddens.squeeze(1))            
            _, predicted = outputs.max(1)                       
            sampled_ids.append(predicted)
            inputs = self.embed(predicted)                       
            inputs = inputs.unsqueeze(1)                        
        sampled_ids = torch.stack(sampled_ids, 1)                
        return sampled_ids

# %%
crop_size=256
val_transform = transforms.Compose([
            transforms.CenterCrop(crop_size),
            transforms.ToTensor(),
            transforms.Normalize((0.444, 0.421, 0.385),
                                 (0.285, 0.277, 0.286))])
val_loader = torch.utils.data.DataLoader(
            dataset=Custom_Flickr30k('flickr30k-images','results_20130124.token', vocab, transform=val_transform, train=False),
            batch_size=16,
            shuffle=False,
            num_workers=2,
            collate_fn=collate_fn)

# %%
embed_size = 512
hidden_size = 1024
num_layers = 1
learning_rate = 1e-4
num_epoch = 10
fine_tune = False
max_BLEU = 0
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

encoder = SimpleEncoderCNN(embed_size, fine_tune).to(device)
decoder = SimpleDecoderRNN(embed_size, hidden_size, len(vocab), num_layers).to(device)


criterion = torch.nn.CrossEntropyLoss()
if fine_tune:
    params = list(encoder.parameters()) + list(decoder.parameters())
else:
    params = list(decoder.parameters()) + list(encoder.linear.parameters()) + list(encoder.bn.parameters())
optimizer = torch.optim.Adam(params, lr=learning_rate)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def bleu_eval(encoder, decoder, data_loader, batch_size, device):
    
    with torch.no_grad():
        features = None
        imgs = None
        caps = None
        encoder.to(device)
        decoder.to(device)
        for i, (images, captions, lengths) in enumerate(data_loader):
            features = encoder(images.to(device))
            imgs = images
            caps = captions
            results = decoder.sample(features)
            true_outputs=[]

            for caption in captions:
                caption = caption.cpu().numpy().astype(str).tolist()
                idx = 0
                curr_img_captions = [[]] 
                for tok in caption[1:-1]:
                    if tok == '4': 
                        idx += 1
                        curr_img_captions.append([])
                    elif tok != '0':
                        curr_img_captions[idx].append(vocab.idx2word[int(tok)])
                true_outputs.append(curr_img_captions)

            predictions = []
            for pred in results:
                curr = []
                for tok in pred:
                    if tok == '2': 
                        break
                    curr.append(vocab.idx2word[int(tok)])
                predicted_caption = []
                for token_index in curr:
                    if token_index == '<end>':
                        break
                    elif token_index == '<start>':
                        continue
                    predicted_caption.append(token_index)
                predictions.append(predicted_caption)

        return nltk.bleu_score.corpus_bleu(true_outputs, predictions, weights=(0.5, 0.5, 0, 0))

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
train_loss = []
bleu_score = []
print(device)
for epoch in range(num_epoch):
    epoch_loss = 0
    for i, (images, captions, lengths) in tqdm(enumerate(data_loader)):
        
        encoder.train()
        decoder.train()

        images = images.to(device)
        captions = captions.to(device)
        targets = pack_padded_sequence(captions, lengths, batch_first=True)[0]

        features = encoder(images)
        features.to(device)
        outputs = decoder(features, captions, lengths)
        loss = criterion(outputs, targets)
        epoch_loss += loss.item()
        decoder.zero_grad()
        encoder.zero_grad()
        loss.backward()
        optimizer.step()
        
    epoch_loss = epoch_loss/1110
    train_loss.append(epoch_loss)
    
    encoder.eval()
    decoder.eval()
    
    score = bleu_eval(encoder, decoder, val_loader, 16, device)
    bleu_score.append(score)
    is_best = score > max_BLEU
    max_BLEU = max(score, max_BLEU)

    if is_best:
        torch.save(encoder, 'encoder_gru_exp.pt')
        torch.save(decoder, 'decoder_gru_exp.pt')

        
    print('Epoch [{}/{}], Loss: {:.4f}'
              .format(epoch+1, num_epoch, epoch_loss))
    print("Bleu Score: ", score)
# Out:
# cuda
# 987it [03:51,  4.26it/s]
# Epoch [1/10], Loss: 3.6561
# Bleu Score:  0.31234752377721214
# 987it [03:51,  4.25it/s]
# Epoch [2/10], Loss: 2.9465
# Bleu Score:  0.2482514050071844
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# 987it [03:50,  4.28it/s]
# Epoch [3/10], Loss: 2.7305
# Bleu Score:  0.3084109455753246
# 987it [03:51,  4.26it/s]
# Epoch [4/10], Loss: 2.5910
# Bleu Score:  0.27524094128159016
# 987it [03:50,  4.27it/s]
# Epoch [5/10], Loss: 2.4893
# Bleu Score:  0.3382550457458691
# 987it [03:51,  4.26it/s]
# Epoch [6/10], Loss: 2.4087
# Bleu Score:  0.28991675380690063
# 987it [03:52,  4.24it/s]
# Epoch [7/10], Loss: 2.3416
# Bleu Score:  0.2804362695493798
# 987it [03:50,  4.28it/s]
# Epoch [8/10], Loss: 2.2832
# Bleu Score:  0.27479969822013345
# 987it [03:51,  4.27it/s]
# Epoch [9/10], Loss: 2.2306
# Bleu Score:  0.3507214933001807
# 987it [03:52,  4.24it/s]
# Epoch [10/10], Loss: 2.1827
# Bleu Score:  0.2572525253299137

# %% [markdown]
# ## Testing Loss Graph Plot

# %%
plt.title('Testing Loss vs Epoch')
plt.plot(train_loss)
plt.xlabel("Epoch")
plt.ylabel("Testing Loss")
# Out:
# Text(0, 0.5, 'Testing Loss')

# %% [markdown]
# # Model Testing

# %%
encoder = torch.load('encoder_gru_exp.pt')
decoder = torch.load('decoder_gru_exp.pt')

# %%
vocab = pickle.load(open('vocab.p', 'rb'))

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
test_transform = transforms.Compose([
            transforms.CenterCrop(crop_size),
            transforms.ToTensor(),
            transforms.Normalize((0.444, 0.421, 0.385),
                                 (0.285, 0.277, 0.286))])

test_loader = torch.utils.data.DataLoader(
            dataset=Custom_Flickr30k('flickr30k-images','results_20130124.token', vocab, transform=test_transform, train=False, test=True),
            batch_size=16,
            shuffle=True,
            num_workers=2,
            collate_fn=collate_fn)

# %%
encoder.to(device)
decoder.to(device)
for i,(images, captions, lengths) in enumerate(test_loader):
    if i>0: break
    features = encoder(images.to(device))
    imgs = images
    caps = captions
    results = decoder.sample(features)
    true_outputs=[]

    for caption in captions:
        caption = caption.cpu().numpy().astype(str).tolist()
        idx = 0
        curr_img_captions = [[]] 
        for tok in caption[1:-1]:
            if tok == '4': 
                idx += 1
                curr_img_captions.append([])
            elif tok != '0':
                curr_img_captions[idx].append(vocab.idx2word[int(tok)])
        true_outputs.append(curr_img_captions)

    predictions = []
    for pred in results:
        curr = []
        for tok in pred:
            if tok == '2':
                break
            curr.append(vocab.idx2word[int(tok)])
        predicted_caption = []
        for token_index in curr:
            if token_index == '<end>':
                break
            elif token_index == '<start>':
                continue
            predicted_caption.append(token_index)
        predictions.append(predicted_caption)
    print(nltk.bleu_score.corpus_bleu(true_outputs, predictions, weights=(1, 0, 0, 0)))
# Out:
# 0.259538022499849

# %%
img = np.transpose(imgs[3], (1, 2, 0))
plt.imshow(img)
print(' '.join(str(word) for word in predictions[3]))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# a woman is sitting at a table with a drink and a man in a black shirt

# %%
img = np.transpose(imgs[0], (1, 2, 0))
plt.imshow(img)
print(' '.join(str(word) for word in predictions[0]))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# a man in a white shirt and black pants is riding a white horse

# %%
img = np.transpose(imgs[1], (1, 2, 0))
plt.imshow(img)
print(' '.join(str(word) for word in predictions[1]))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# a man in a blue shirt is standing in front of a microphone

# %%
img = np.transpose(imgs[7], (1, 2, 0))
plt.imshow(img)
print(' '.join(str(word) for word in predictions[7]))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# a group of people are running in a field

# %%
img = np.transpose(imgs[6], (1, 2, 0))
plt.imshow(img)
print(' '.join(str(word) for word in predictions[6]))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# a skateboarder is doing a trick on a ramp
